# %%
import requests
import pandas as pd

# %%
import sys, os
SRC_PATH = os.path.join(os.getcwd(), "..")  # adjust depending on notebook location
if SRC_PATH not in sys.path:
    sys.path.insert(0, SRC_PATH)
from utils.config import *

print("Project root:", os.path.dirname(DATA_PATH))
print("Data folder exists?", os.path.exists(DATA_PATH))
print("Sample file exists?", os.path.exists(os.path.join(DATA_PATH, "abstract_sample_data.csv")))
# Out:
# Project root: c:\Users\Pau\Files\Estudis\UOC\TFM\Graph_Rag
# Data folder exists? True
# Sample file exists? True

# %%
# ----------------------------------------
# Notebook: DBpedia Pipeline Debugging
# Start from load_local_data()
# ----------------------------------------
import pandas as pd
from data_intake import load_local_data
from text_preprocessing import chunk_dataframe
from dbpedia_pipeline import (
    annotate_text_spotlight,
    enrich_annotations,
    clean_parsed_entities
)

# %%
# ----------------------------------------
# Step 0 — Load local data
# ----------------------------------------
metadata_df, text_df = load_local_data()
print(f"Metadata entries: {len(metadata_df)}")
display(metadata_df.head())

print(f"Text entries: {len(text_df)}")
display(text_df.head())
# Out:
# 2025-10-20 22:03:06,237 | INFO | Loading dataset from c:\Users\Pau\Files\Estudis\UOC\TFM\Graph_Rag\data\abstract_sample_data.csv...
# 2025-10-20 22:03:06,258 | INFO | Sample affiliations_clean: [{'@_fa': 'true', 'affilname': 'Shanghai University of International Business and Economics', 'affiliation-city': 'Shanghai', 'affiliation-country': 'China'}]
# 2025-10-20 22:03:06,260 | INFO | Sample links_clean: {}
# 2025-10-20 22:03:06,261 | INFO | Loaded 23 metadata entries.
# Metadata entries: 23
#      scopus_id                                              title  \
# 0  85195362067  Optimization Study of Higher Education Data Go...
# 1  85181155120  Educational Missions and Tactics in the EU Art...
# 2  85183323712  The European AI Tango: Balancing Regulation In...
# 3  85179647045               Medicine’s Lessons for AI Regulation
# 4  85181147353  Application of AI Technology in Online Platfor...
#
#        creator                                   publication_name  cover_date  \
# 0      Chen J.     ACM International Conference Proceeding Series  2023-12-22
# 1     Xiong Y.          Advances in Transdisciplinary Engineering  2023-12-15
# 2  Todorova C.     ACM International Conference Proceeding Series  2023-12-14
# 3     Stark L.                    New England Journal of Medicine  2023-12-14
# 4      Zhou Q.  Frontiers in Artificial Intelligence and Appli...  2023-12-12
#
#        subtype_desc                                       affiliations links
# 0  Conference Paper  [{'@_fa': 'true', 'affilname': 'Shanghai Unive...    {}
# 1  Conference Paper  [{'@_fa': 'true', 'affilname': 'Wenzhou Univer...    {}
# 2  Conference Paper  [{'@_fa': 'true', 'affilname': 'European Softw...    {}
# 3           Article  [{'@_fa': 'true', 'affilname': 'Vanderbilt Uni...    {}
# 4  Conference Paper  [{'@_fa': 'true', 'affilname': 'Anhui Sanlian ...    {}
# Text entries: 23
#      scopus_id                                        description  abstract
# 0  85195362067  Artificial intelligence technology has opened ...       NaN
# 1  85181155120  In the era of digital transformation, AI, clou...       NaN
# 2  85183323712  In the past few years, the EU has shown a grow...       NaN
# 3  85179647045  There are various possible futures for regulat...       NaN
# 4  85181147353  In order to cater to the reform of online plat...       NaN

# %%
# ----------------------------------------
# Step 1 — Chunk text
# ----------------------------------------
chunks_df = chunk_dataframe(text_df, text_col="description", id_col="scopus_id")
print(f"Chunks created: {len(chunks_df)}")
display(chunks_df.head())
# Out:
# Chunks created: 41
#      scopus_id  chunk_id                                         chunk_text
# 0  85195362067         0  Artificial intelligence technology has opened ...
# 1  85195362067         1  seven evaluation indicators and three stages o...
# 2  85181155120         0  In the era of digital transformation, AI, clou...
# 3  85181155120         1  the EU has adopted various education tactics i...
# 4  85183323712         0  In the past few years, the EU has shown a grow...

# %%
# ----------------------------------------
# Step 2 — Annotate original text with DBpedia entries
# ----------------------------------------
sample_chunks = chunks_df.head(20)  # testing first 20 chunks
all_annotations = []

print("\nStep 2 — Annotating chunks with DBpedia Spotlight...")
all_annotations = []

for idx, row in sample_chunks.iterrows():
    article_id = row['scopus_id']
    chunk_id = row['chunk_id']
    text = row['chunk_text']

    print(f"\nChunk {idx+1}: {text[:80]}...")
    annotations = annotate_text_spotlight(article_id, chunk_id, text, confidence=0.5)
    print(f"Annotations ({len(annotations)}): {annotations}")
    all_annotations.extend(annotations)  # flatten here to simplify enrichment
# Out:
# Step 2 — Annotating chunks with DBpedia Spotlight...
#
# Chunk 1: Artificial intelligence technology has opened up new horizons for higher educati...
# Annotations (10): [(85195362067, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'Artificial intelligence', 0.9999998141935466), (85195362067, 0, 'http://dbpedia.org/resource/Data_governance', 'data governance', 1.0), (85195362067, 0, 'http://dbpedia.org/resource/Data_dependency', 'data dependency', 1.0), (85195362067, 0, 'http://dbpedia.org/resource/Hinder', 'hinder', 0.9999999184987052), (85195362067, 0, 'http://dbpedia.org/resource/Data_sharing', 'data sharing', 1.0), (85195362067, 0, 'http://dbpedia.org/resource/Privacy', 'privacy', 0.9973295876647092), (85195362067, 0, 'http://dbpedia.org/resource/Data_sharing', 'data sharing', 1.0), (85195362067, 0, 'http://dbpedia.org/resource/Data_governance', 'data governance', 1.0), (85195362067, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.9999903076865347), (85195362067, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.9999903076865347)]
#
# Chunk 2: seven evaluation indicators and three stages of dynamic changes. This model will...
# Annotations (2): [(85195362067, 1, 'http://dbpedia.org/resource/China', 'China', 0.9984880813811061), (85195362067, 1, 'http://dbpedia.org/resource/Mathematical_optimization', 'optimization', 0.9924677316381805)]
#
# Chunk 3: In the era of digital transformation, AI, cloud computing, big data, blockchain,...
# Annotations (16): [(85181155120, 0, 'http://dbpedia.org/resource/Digital_transformation', 'digital transformation', 1.0), (85181155120, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.9999999999791953), (85181155120, 0, 'http://dbpedia.org/resource/Cloud_computing', 'cloud computing', 1.0), (85181155120, 0, 'http://dbpedia.org/resource/Big_data', 'big data', 1.0), (85181155120, 0, 'http://dbpedia.org/resource/Blockchain', 'blockchain', 0.9999997604824389), (85181155120, 0, 'http://dbpedia.org/resource/The_Age', 'The Age', 1.0), (85181155120, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'Artificial Intelligence', 0.9999999991963477), (85181155120, 0, 'http://dbpedia.org/resource/European_Union', 'EU', 0.9999977382934159), (85181155120, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'Artificial Intelligence', 0.9999999991963477), (85181155120, 0, 'http://dbpedia.org/resource/European_Union', 'EU', 0.9999977382934159), (85181155120, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'Artificial Intelligence', 0.9999999991963477), (85181155120, 0, 'http://dbpedia.org/resource/European_Commission', 'European Commission', 0.9999999975307219), (85181155120, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.9999999999791953), (85181155120, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.9999999999791953), (85181155120, 0, 'http://dbpedia.org/resource/European_Union', 'EU', 0.9999977382934159), (85181155120, 0, 'http://dbpedia.org/resource/European_Union', 'EU', 0.9999977382934159)]
#
# Chunk 4: the EU has adopted various education tactics in the series of documents. Given t...
# Annotations (6): [(85181155120, 1, 'http://dbpedia.org/resource/European_Union', 'EU', 0.9991469132205403), (85181155120, 1, 'http://dbpedia.org/resource/European_Union', 'EU', 0.9991469132205403), (85181155120, 1, 'http://dbpedia.org/resource/Philosophy', 'philosophy', 0.9998373038336702), (85181155120, 1, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.997991788197381), (85181155120, 1, 'http://dbpedia.org/resource/Digital_transformation', 'digital transformation', 1.0), (85181155120, 1, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.997991788197381)]
#
# Chunk 5: In the past few years, the EU has shown a growing commitment to address the rapi...
# Annotations (13): [(85183323712, 0, 'http://dbpedia.org/resource/European_Union', 'EU', 0.9999754610408187), (85183323712, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'Artificial Intelligence', 0.9999999999931788), (85183323712, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.9999999856870546), (85183323712, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.9999999856870546), (85183323712, 0, 'http://dbpedia.org/resource/European_Union', 'Europe', 0.998332783478284), (85183323712, 0, 'http://dbpedia.org/resource/Hinder', 'hinder', 0.9999999671592837), (85183323712, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.9999999856870546), (85183323712, 0, 'http://dbpedia.org/resource/United_States', 'United States', 0.9984799994745319), (85183323712, 0, 'http://dbpedia.org/resource/Asia', 'Asia', 0.9998897737157746), (85183323712, 0, 'http://dbpedia.org/resource/European_Union', 'Europe', 0.998332783478284), (85183323712, 0, 'http://dbpedia.org/resource/KCMP', 'The current', 0.9999999704256202), (85183323712, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.9999999856870546), (85183323712, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.9999999856870546)]
#
# Chunk 6: competitiveness of European technology. This paper only explores recent AI regul...
# Annotations (7): [(85183323712, 1, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.9999993412255785), (85183323712, 1, 'http://dbpedia.org/resource/European_Union', 'Europe', 0.9798240271525648), (85183323712, 1, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.9999993412255785), (85183323712, 1, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.9999993412255785), (85183323712, 1, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.9999993412255785), (85183323712, 1, 'http://dbpedia.org/resource/European_Union', 'Europe', 0.9798240271525648), (85183323712, 1, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.9999993412255785)]
#
# Chunk 7: There are various possible futures for regulation of artificial intelligence in ...
# Annotations (2): [(85179647045, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'artificial intelligence', 0.9986413620919127), (85179647045, 0, 'http://dbpedia.org/resource/United_States', 'United States', 0.9993627949014026)]
#
# Chunk 8: In order to cater to the reform of online platforms and improve online users’ le...
# Annotations (4): [(85181147353, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.9999985948032514), (85181147353, 0, 'http://dbpedia.org/resource/Cognition', 'cognitive', 0.9998910294910631), (85181147353, 0, 'http://dbpedia.org/resource/Emotional_self-regulation', 'emotion regulation', 0.9999999588948763), (85181147353, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.9999985948032514)]
#
# Chunk 9: Indonesia relies too much on oil as an energy source and does not make full effo...
# Annotations (15): [(85180385835, 0, 'http://dbpedia.org/resource/Indonesia', 'Indonesia', 0.999799185906419), (85180385835, 0, 'http://dbpedia.org/resource/Energy_development', 'energy', 0.7523010359286494), (85180385835, 0, 'http://dbpedia.org/resource/Renewable_energy', 'alternative energy', 0.990403652642572), (85180385835, 0, 'http://dbpedia.org/resource/Energy_security', 'energy security', 0.9999999999364491), (85180385835, 0, 'http://dbpedia.org/resource/Energy_security', 'energy security', 0.9999999999364491), (85180385835, 0, 'http://dbpedia.org/resource/Rationality', 'rationality', 0.9387555895955757), (85180385835, 0, 'http://dbpedia.org/resource/Energy_management', 'energy management', 0.9999986851410771), (85180385835, 0, 'http://dbpedia.org/resource/Energy_development', 'energy', 0.7523010359286494), (85180385835, 0, 'http://dbpedia.org/resource/Renewable_energy', 'alternative energy', 0.990403652642572), (85180385835, 0, 'http://dbpedia.org/resource/Biomass', 'biomass', 0.994075057946526), (85180385835, 0, 'http://dbpedia.org/resource/Briquette', 'briquettes', 1.0), (85180385835, 0, 'http://dbpedia.org/resource/Biodegradable_waste', 'organic waste', 0.9990696038605332), (85180385835, 0, 'http://dbpedia.org/resource/Smart_city', 'smart city', 1.0), (85180385835, 0, 'http://dbpedia.org/resource/City', 'city', 0.9998800900498179), (85180385835, 0, 'http://dbpedia.org/resource/Renewable_energy', 'alternative energy', 0.990403652642572)]
#
# Chunk 10: waste sources into alternative energy for community needs. The research question...
# Annotations (20): [(85180385835, 1, 'http://dbpedia.org/resource/Renewable_energy', 'alternative energy', 0.9989240104233678), (85180385835, 1, 'http://dbpedia.org/resource/Mathematical_optimization', 'optimization algorithm', 1.0), (85180385835, 1, 'http://dbpedia.org/resource/Biomass', 'biomass', 0.9999996870775966), (85180385835, 1, 'http://dbpedia.org/resource/Briquette', 'briquette', 1.0), (85180385835, 1, 'http://dbpedia.org/resource/Mathematical_optimization', 'optimization algorithm', 1.0), (85180385835, 1, 'http://dbpedia.org/resource/Biomass', 'biomass', 0.9999996870775966), (85180385835, 1, 'http://dbpedia.org/resource/Briquette', 'briquette', 1.0), (85180385835, 1, 'http://dbpedia.org/resource/Artificial_intelligence', 'Artificial intelligence', 0.9999999906827952), (85180385835, 1, 'http://dbpedia.org/resource/Biodegradable_waste', 'organic waste', 0.8926140659275767), (85180385835, 1, 'http://dbpedia.org/resource/Biomass', 'biomass', 0.9999996870775966), (85180385835, 1, 'http://dbpedia.org/resource/Briquette', 'briquettes', 1.0), (85180385835, 1, 'http://dbpedia.org/resource/Biodegradable_waste', 'organic waste', 0.8926140659275767), (85180385835, 1, 'http://dbpedia.org/resource/Biomass', 'biomass', 0.9999996870775966), (85180385835, 1, 'http://dbpedia.org/resource/Briquette', 'briquettes', 1.0), (85180385835, 1, 'http://dbpedia.org/resource/Artificial_neural_network', 'Artificial Neural Network', 1.0), (85180385835, 1, 'http://dbpedia.org/resource/Artificial_neural_network', 'ANN', 1.0), (85180385835, 1, 'http://dbpedia.org/resource/MATLAB', 'Matlab', 1.0), (85180385835, 1, 'http://dbpedia.org/resource/Mathematical_optimization', 'programming', 0.9998630697130553), (85180385835, 1, 'http://dbpedia.org/resource/Biodegradable_waste', 'organic waste', 0.8926140659275767), (85180385835, 1, 'http://dbpedia.org/resource/Biomass', 'biomass', 0.9999996870775966)]
#
# Chunk 11: potential to produce quality biomass...
# Annotations (1): [(85180385835, 2, 'http://dbpedia.org/resource/Biomass', 'biomass', 0.9988220189016228)]
#
# Chunk 12: This study underscores the importance of standard data analytics governance with...
# Annotations (10): [(85180763362, 0, 'http://dbpedia.org/resource/Big_data', 'big data', 1.0), (85180763362, 0, 'http://dbpedia.org/resource/Thailand', 'Thailand', 0.9999900473919352), (85180763362, 0, 'http://dbpedia.org/resource/Data_governance', 'data governance', 1.0), (85180763362, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.999999955352565), (85180763362, 0, 'http://dbpedia.org/resource/Digital_Government_Development_Agency', 'Digital Government Development Agency', 1.0), (85180763362, 0, 'http://dbpedia.org/resource/Directors_Guild_of_America', 'DGA', 0.9770269019662101), (85180763362, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'Artificial Intelligence', 0.9999307321999056), (85180763362, 0, 'http://dbpedia.org/resource/Electronic_business', 'e-Business', 1.0), (85180763362, 0, 'http://dbpedia.org/resource/Thailand', 'Thailand', 0.9999900473919352), (85180763362, 0, 'http://dbpedia.org/resource/Data_governance', 'data governance', 1.0)]
#
# Chunk 13: in Thailand, which have already implemented data governance....
# Annotations (2): [(85180763362, 1, 'http://dbpedia.org/resource/Thailand', 'Thailand', 0.9997677458695996), (85180763362, 1, 'http://dbpedia.org/resource/Data_governance', 'data governance', 0.9999999996262261)]
#
# Chunk 14: Personal autonomy is at the core of liberal societies, and its preservation has ...
# Annotations (12): [(85170835273, 0, 'http://dbpedia.org/resource/United_States', 'Union', 0.9988666190946556), (85170835273, 0, 'http://dbpedia.org/resource/European_Union', 'EU', 0.9999462133430398), (85170835273, 0, 'http://dbpedia.org/resource/General_Data_Protection_Regulation', 'data protection', 0.9369839664980887), (85170835273, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'artificial intelligence', 0.9999990354437036), (85170835273, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'artificial intelligence', 0.9999990354437036), (85170835273, 0, 'http://dbpedia.org/resource/Targeted_advertising', 'behavioural advertising', 1.0), (85170835273, 0, 'http://dbpedia.org/resource/Recommender_system', 'recommender systems', 1.0), (85170835273, 0, 'http://dbpedia.org/resource/European_Union', 'EU', 0.9999462133430398), (85170835273, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'artificial intelligence', 0.9999990354437036), (85170835273, 0, 'http://dbpedia.org/resource/European_Union', 'EU', 0.9999462133430398), (85170835273, 0, 'http://dbpedia.org/resource/European_Union', 'EU', 0.9999462133430398), (85170835273, 0, 'http://dbpedia.org/resource/General_Data_Protection_Regulation', 'data protection', 0.9369839664980887)]
#
# Chunk 15: the paper makes several proposals to integrate the long-term risks affecting con...
# Annotations (5): [(85170835273, 1, 'http://dbpedia.org/resource/European_Union', 'EU', 0.998623795411186), (85170835273, 1, 'http://dbpedia.org/resource/Information_privacy', 'data protection', 0.996660284653181), (85170835273, 1, 'http://dbpedia.org/resource/Philosophy', 'philosophy', 0.9964982610630854), (85170835273, 1, 'http://dbpedia.org/resource/Ethics', 'ethics', 0.9990895999803939), (85170835273, 1, 'http://dbpedia.org/resource/Computer_science', 'computer science', 0.9998233743480225)]
#
# Chunk 16: Big Data (BD) and Artificial Intelligence (AI) play a fundamental role in today’...
# Annotations (9): [(85172381433, 0, 'http://dbpedia.org/resource/Big_data', 'Big Data', 1.0), (85172381433, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'Artificial Intelligence', 0.8200238026257817), (85172381433, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.9995484061633424), (85172381433, 0, 'http://dbpedia.org/resource/Data_economy', 'data economy', 1.0), (85172381433, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.9995484061633424), (85172381433, 0, 'http://dbpedia.org/resource/Data_sharing', 'data sharing', 1.0), (85172381433, 0, 'http://dbpedia.org/resource/Data_sharing', 'data sharing', 1.0), (85172381433, 0, 'http://dbpedia.org/resource/Data_capitalism', 'data capitalism', 1.0), (85172381433, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.9995484061633424)]
#
# Chunk 17: A broad range of companies around the world has welcomed artificial intelligence...
# Annotations (12): [(85168476791, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'artificial intelligence', 0.9999999522445944), (85168476791, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.9999999948211098), (85168476791, 0, 'http://dbpedia.org/resource/Baseball_statistics', 'assists', 0.6119579946813937), (85168476791, 0, 'http://dbpedia.org/resource/Hysteresis', 'hysteresis', 0.9682452705604025), (85168476791, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.9999999948211098), (85168476791, 0, 'http://dbpedia.org/resource/Internal_audit', 'internal audit', 1.0), (85168476791, 0, 'http://dbpedia.org/resource/Soft_computing', 'soft computing', 1.0), (85168476791, 0, 'http://dbpedia.org/resource/Set_theory', 'set theory', 0.9996315799171818), (85168476791, 0, 'http://dbpedia.org/resource/Algorithm', 'algorithm', 0.9999460479339639), (85168476791, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.9999999948211098), (85168476791, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.9999999948211098), (85168476791, 0, 'http://dbpedia.org/resource/Data_infrastructure', 'data infrastructure', 1.0)]
#
# Chunk 18: order of priority in improvement—(A) AI application strategy, (B) AI governance,...
# Annotations (6): [(85168476791, 1, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.9999998988656722), (85168476791, 1, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.9999998988656722), (85168476791, 1, 'http://dbpedia.org/resource/Data_infrastructure', 'data infrastructure', 1.0), (85168476791, 1, 'http://dbpedia.org/resource/Apparent_magnitude', 'magnitude', 0.9110009595088079), (85168476791, 1, 'http://dbpedia.org/resource/Internal_audit', 'internal audit', 1.0), (85168476791, 1, 'http://dbpedia.org/resource/Big_data', 'big data', 1.0)]
#
# Chunk 19: It is widely accepted that directors’ duties encompass the duty to prepare and a...
# Annotations (6): [(85198853040, 0, 'http://dbpedia.org/resource/Board_of_directors', "directors' duties", 0.948482501806565), (85198853040, 0, 'http://dbpedia.org/resource/Business_judgment_rule', 'business judgment rule', 1.0), (85198853040, 0, 'http://dbpedia.org/resource/Rationality', 'rationality', 0.9999154664778693), (85198853040, 0, 'http://dbpedia.org/resource/Insolvency', 'insolvency', 0.8452439962288453), (85198853040, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'artificial intelligence', 0.9998944694632593), (85198853040, 0, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.9999978237017138)]
#
# Chunk 20: are a number of options of technologies that employ artificial intelligence (AI)...
# Annotations (5): [(85198853040, 1, 'http://dbpedia.org/resource/Artificial_intelligence', 'artificial intelligence', 0.999968005997915), (85198853040, 1, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.999951842725345), (85198853040, 1, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.999951842725345), (85198853040, 1, 'http://dbpedia.org/resource/Artificial_intelligence', 'AI', 0.999951842725345), (85198853040, 1, 'http://dbpedia.org/resource/Corporate_governance', 'corporate governance', 0.9999999889737411)]

# %%
display(all_annotations)
# Out:
# [(85195362067,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'Artificial intelligence',
#   0.9999998141935466),
#  (85195362067,
#   0,
#   'http://dbpedia.org/resource/Data_governance',
#   'data governance',
#   1.0),
#  (85195362067,
#   0,
#   'http://dbpedia.org/resource/Data_dependency',
#   'data dependency',
#   1.0),
#  (85195362067,
#   0,
#   'http://dbpedia.org/resource/Hinder',
#   'hinder',
#   0.9999999184987052),
#  (85195362067,
#   0,
#   'http://dbpedia.org/resource/Data_sharing',
#   'data sharing',
#   1.0),
#  (85195362067,
#   0,
#   'http://dbpedia.org/resource/Privacy',
#   'privacy',
#   0.9973295876647092),
#  (85195362067,
#   0,
#   'http://dbpedia.org/resource/Data_sharing',
#   'data sharing',
#   1.0),
#  (85195362067,
#   0,
#   'http://dbpedia.org/resource/Data_governance',
#   'data governance',
#   1.0),
#  (85195362067,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.9999903076865347),
#  (85195362067,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.9999903076865347),
#  (85195362067,
#   1,
#   'http://dbpedia.org/resource/China',
#   'China',
#   0.9984880813811061),
#  (85195362067,
#   1,
#   'http://dbpedia.org/resource/Mathematical_optimization',
#   'optimization',
#   0.9924677316381805),
#  (85181155120,
#   0,
#   'http://dbpedia.org/resource/Digital_transformation',
#   'digital transformation',
#   1.0),
#  (85181155120,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.9999999999791953),
#  (85181155120,
#   0,
#   'http://dbpedia.org/resource/Cloud_computing',
#   'cloud computing',
#   1.0),
#  (85181155120, 0, 'http://dbpedia.org/resource/Big_data', 'big data', 1.0),
#  (85181155120,
#   0,
#   'http://dbpedia.org/resource/Blockchain',
#   'blockchain',
#   0.9999997604824389),
#  (85181155120, 0, 'http://dbpedia.org/resource/The_Age', 'The Age', 1.0),
#  (85181155120,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'Artificial Intelligence',
#   0.9999999991963477),
#  (85181155120,
#   0,
#   'http://dbpedia.org/resource/European_Union',
#   'EU',
#   0.9999977382934159),
#  (85181155120,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'Artificial Intelligence',
#   0.9999999991963477),
#  (85181155120,
#   0,
#   'http://dbpedia.org/resource/European_Union',
#   'EU',
#   0.9999977382934159),
#  (85181155120,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'Artificial Intelligence',
#   0.9999999991963477),
#  (85181155120,
#   0,
#   'http://dbpedia.org/resource/European_Commission',
#   'European Commission',
#   0.9999999975307219),
#  (85181155120,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.9999999999791953),
#  (85181155120,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.9999999999791953),
#  (85181155120,
#   0,
#   'http://dbpedia.org/resource/European_Union',
#   'EU',
#   0.9999977382934159),
#  (85181155120,
#   0,
#   'http://dbpedia.org/resource/European_Union',
#   'EU',
#   0.9999977382934159),
#  (85181155120,
#   1,
#   'http://dbpedia.org/resource/European_Union',
#   'EU',
#   0.9991469132205403),
#  (85181155120,
#   1,
#   'http://dbpedia.org/resource/European_Union',
#   'EU',
#   0.9991469132205403),
#  (85181155120,
#   1,
#   'http://dbpedia.org/resource/Philosophy',
#   'philosophy',
#   0.9998373038336702),
#  (85181155120,
#   1,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.997991788197381),
#  (85181155120,
#   1,
#   'http://dbpedia.org/resource/Digital_transformation',
#   'digital transformation',
#   1.0),
#  (85181155120,
#   1,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.997991788197381),
#  (85183323712,
#   0,
#   'http://dbpedia.org/resource/European_Union',
#   'EU',
#   0.9999754610408187),
#  (85183323712,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'Artificial Intelligence',
#   0.9999999999931788),
#  (85183323712,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.9999999856870546),
#  (85183323712,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.9999999856870546),
#  (85183323712,
#   0,
#   'http://dbpedia.org/resource/European_Union',
#   'Europe',
#   0.998332783478284),
#  (85183323712,
#   0,
#   'http://dbpedia.org/resource/Hinder',
#   'hinder',
#   0.9999999671592837),
#  (85183323712,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.9999999856870546),
#  (85183323712,
#   0,
#   'http://dbpedia.org/resource/United_States',
#   'United States',
#   0.9984799994745319),
#  (85183323712,
#   0,
#   'http://dbpedia.org/resource/Asia',
#   'Asia',
#   0.9998897737157746),
#  (85183323712,
#   0,
#   'http://dbpedia.org/resource/European_Union',
#   'Europe',
#   0.998332783478284),
#  (85183323712,
#   0,
#   'http://dbpedia.org/resource/KCMP',
#   'The current',
#   0.9999999704256202),
#  (85183323712,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.9999999856870546),
#  (85183323712,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.9999999856870546),
#  (85183323712,
#   1,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.9999993412255785),
#  (85183323712,
#   1,
#   'http://dbpedia.org/resource/European_Union',
#   'Europe',
#   0.9798240271525648),
#  (85183323712,
#   1,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.9999993412255785),
#  (85183323712,
#   1,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.9999993412255785),
#  (85183323712,
#   1,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.9999993412255785),
#  (85183323712,
#   1,
#   'http://dbpedia.org/resource/European_Union',
#   'Europe',
#   0.9798240271525648),
#  (85183323712,
#   1,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.9999993412255785),
#  (85179647045,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'artificial intelligence',
#   0.9986413620919127),
#  (85179647045,
#   0,
#   'http://dbpedia.org/resource/United_States',
#   'United States',
#   0.9993627949014026),
#  (85181147353,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.9999985948032514),
#  (85181147353,
#   0,
#   'http://dbpedia.org/resource/Cognition',
#   'cognitive',
#   0.9998910294910631),
#  (85181147353,
#   0,
#   'http://dbpedia.org/resource/Emotional_self-regulation',
#   'emotion regulation',
#   0.9999999588948763),
#  (85181147353,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.9999985948032514),
#  (85180385835,
#   0,
#   'http://dbpedia.org/resource/Indonesia',
#   'Indonesia',
#   0.999799185906419),
#  (85180385835,
#   0,
#   'http://dbpedia.org/resource/Energy_development',
#   'energy',
#   0.7523010359286494),
#  (85180385835,
#   0,
#   'http://dbpedia.org/resource/Renewable_energy',
#   'alternative energy',
#   0.990403652642572),
#  (85180385835,
#   0,
#   'http://dbpedia.org/resource/Energy_security',
#   'energy security',
#   0.9999999999364491),
#  (85180385835,
#   0,
#   'http://dbpedia.org/resource/Energy_security',
#   'energy security',
#   0.9999999999364491),
#  (85180385835,
#   0,
#   'http://dbpedia.org/resource/Rationality',
#   'rationality',
#   0.9387555895955757),
#  (85180385835,
#   0,
#   'http://dbpedia.org/resource/Energy_management',
#   'energy management',
#   0.9999986851410771),
#  (85180385835,
#   0,
#   'http://dbpedia.org/resource/Energy_development',
#   'energy',
#   0.7523010359286494),
#  (85180385835,
#   0,
#   'http://dbpedia.org/resource/Renewable_energy',
#   'alternative energy',
#   0.990403652642572),
#  (85180385835,
#   0,
#   'http://dbpedia.org/resource/Biomass',
#   'biomass',
#   0.994075057946526),
#  (85180385835, 0, 'http://dbpedia.org/resource/Briquette', 'briquettes', 1.0),
#  (85180385835,
#   0,
#   'http://dbpedia.org/resource/Biodegradable_waste',
#   'organic waste',
#   0.9990696038605332),
#  (85180385835, 0, 'http://dbpedia.org/resource/Smart_city', 'smart city', 1.0),
#  (85180385835,
#   0,
#   'http://dbpedia.org/resource/City',
#   'city',
#   0.9998800900498179),
#  (85180385835,
#   0,
#   'http://dbpedia.org/resource/Renewable_energy',
#   'alternative energy',
#   0.990403652642572),
#  (85180385835,
#   1,
#   'http://dbpedia.org/resource/Renewable_energy',
#   'alternative energy',
#   0.9989240104233678),
#  (85180385835,
#   1,
#   'http://dbpedia.org/resource/Mathematical_optimization',
#   'optimization algorithm',
#   1.0),
#  (85180385835,
#   1,
#   'http://dbpedia.org/resource/Biomass',
#   'biomass',
#   0.9999996870775966),
#  (85180385835, 1, 'http://dbpedia.org/resource/Briquette', 'briquette', 1.0),
#  (85180385835,
#   1,
#   'http://dbpedia.org/resource/Mathematical_optimization',
#   'optimization algorithm',
#   1.0),
#  (85180385835,
#   1,
#   'http://dbpedia.org/resource/Biomass',
#   'biomass',
#   0.9999996870775966),
#  (85180385835, 1, 'http://dbpedia.org/resource/Briquette', 'briquette', 1.0),
#  (85180385835,
#   1,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'Artificial intelligence',
#   0.9999999906827952),
#  (85180385835,
#   1,
#   'http://dbpedia.org/resource/Biodegradable_waste',
#   'organic waste',
#   0.8926140659275767),
#  (85180385835,
#   1,
#   'http://dbpedia.org/resource/Biomass',
#   'biomass',
#   0.9999996870775966),
#  (85180385835, 1, 'http://dbpedia.org/resource/Briquette', 'briquettes', 1.0),
#  (85180385835,
#   1,
#   'http://dbpedia.org/resource/Biodegradable_waste',
#   'organic waste',
#   0.8926140659275767),
#  (85180385835,
#   1,
#   'http://dbpedia.org/resource/Biomass',
#   'biomass',
#   0.9999996870775966),
#  (85180385835, 1, 'http://dbpedia.org/resource/Briquette', 'briquettes', 1.0),
#  (85180385835,
#   1,
#   'http://dbpedia.org/resource/Artificial_neural_network',
#   'Artificial Neural Network',
#   1.0),
#  (85180385835,
#   1,
#   'http://dbpedia.org/resource/Artificial_neural_network',
#   'ANN',
#   1.0),
#  (85180385835, 1, 'http://dbpedia.org/resource/MATLAB', 'Matlab', 1.0),
#  (85180385835,
#   1,
#   'http://dbpedia.org/resource/Mathematical_optimization',
#   'programming',
#   0.9998630697130553),
#  (85180385835,
#   1,
#   'http://dbpedia.org/resource/Biodegradable_waste',
#   'organic waste',
#   0.8926140659275767),
#  (85180385835,
#   1,
#   'http://dbpedia.org/resource/Biomass',
#   'biomass',
#   0.9999996870775966),
#  (85180385835,
#   2,
#   'http://dbpedia.org/resource/Biomass',
#   'biomass',
#   0.9988220189016228),
#  (85180763362, 0, 'http://dbpedia.org/resource/Big_data', 'big data', 1.0),
#  (85180763362,
#   0,
#   'http://dbpedia.org/resource/Thailand',
#   'Thailand',
#   0.9999900473919352),
#  (85180763362,
#   0,
#   'http://dbpedia.org/resource/Data_governance',
#   'data governance',
#   1.0),
#  (85180763362,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.999999955352565),
#  (85180763362,
#   0,
#   'http://dbpedia.org/resource/Digital_Government_Development_Agency',
#   'Digital Government Development Agency',
#   1.0),
#  (85180763362,
#   0,
#   'http://dbpedia.org/resource/Directors_Guild_of_America',
#   'DGA',
#   0.9770269019662101),
#  (85180763362,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'Artificial Intelligence',
#   0.9999307321999056),
#  (85180763362,
#   0,
#   'http://dbpedia.org/resource/Electronic_business',
#   'e-Business',
#   1.0),
#  (85180763362,
#   0,
#   'http://dbpedia.org/resource/Thailand',
#   'Thailand',
#   0.9999900473919352),
#  (85180763362,
#   0,
#   'http://dbpedia.org/resource/Data_governance',
#   'data governance',
#   1.0),
#  (85180763362,
#   1,
#   'http://dbpedia.org/resource/Thailand',
#   'Thailand',
#   0.9997677458695996),
#  (85180763362,
#   1,
#   'http://dbpedia.org/resource/Data_governance',
#   'data governance',
#   0.9999999996262261),
#  (85170835273,
#   0,
#   'http://dbpedia.org/resource/United_States',
#   'Union',
#   0.9988666190946556),
#  (85170835273,
#   0,
#   'http://dbpedia.org/resource/European_Union',
#   'EU',
#   0.9999462133430398),
#  (85170835273,
#   0,
#   'http://dbpedia.org/resource/General_Data_Protection_Regulation',
#   'data protection',
#   0.9369839664980887),
#  (85170835273,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'artificial intelligence',
#   0.9999990354437036),
#  (85170835273,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'artificial intelligence',
#   0.9999990354437036),
#  (85170835273,
#   0,
#   'http://dbpedia.org/resource/Targeted_advertising',
#   'behavioural advertising',
#   1.0),
#  (85170835273,
#   0,
#   'http://dbpedia.org/resource/Recommender_system',
#   'recommender systems',
#   1.0),
#  (85170835273,
#   0,
#   'http://dbpedia.org/resource/European_Union',
#   'EU',
#   0.9999462133430398),
#  (85170835273,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'artificial intelligence',
#   0.9999990354437036),
#  (85170835273,
#   0,
#   'http://dbpedia.org/resource/European_Union',
#   'EU',
#   0.9999462133430398),
#  (85170835273,
#   0,
#   'http://dbpedia.org/resource/European_Union',
#   'EU',
#   0.9999462133430398),
#  (85170835273,
#   0,
#   'http://dbpedia.org/resource/General_Data_Protection_Regulation',
#   'data protection',
#   0.9369839664980887),
#  (85170835273,
#   1,
#   'http://dbpedia.org/resource/European_Union',
#   'EU',
#   0.998623795411186),
#  (85170835273,
#   1,
#   'http://dbpedia.org/resource/Information_privacy',
#   'data protection',
#   0.996660284653181),
#  (85170835273,
#   1,
#   'http://dbpedia.org/resource/Philosophy',
#   'philosophy',
#   0.9964982610630854),
#  (85170835273,
#   1,
#   'http://dbpedia.org/resource/Ethics',
#   'ethics',
#   0.9990895999803939),
#  (85170835273,
#   1,
#   'http://dbpedia.org/resource/Computer_science',
#   'computer science',
#   0.9998233743480225),
#  (85172381433, 0, 'http://dbpedia.org/resource/Big_data', 'Big Data', 1.0),
#  (85172381433,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'Artificial Intelligence',
#   0.8200238026257817),
#  (85172381433,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.9995484061633424),
#  (85172381433,
#   0,
#   'http://dbpedia.org/resource/Data_economy',
#   'data economy',
#   1.0),
#  (85172381433,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.9995484061633424),
#  (85172381433,
#   0,
#   'http://dbpedia.org/resource/Data_sharing',
#   'data sharing',
#   1.0),
#  (85172381433,
#   0,
#   'http://dbpedia.org/resource/Data_sharing',
#   'data sharing',
#   1.0),
#  (85172381433,
#   0,
#   'http://dbpedia.org/resource/Data_capitalism',
#   'data capitalism',
#   1.0),
#  (85172381433,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.9995484061633424),
#  (85168476791,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'artificial intelligence',
#   0.9999999522445944),
#  (85168476791,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.9999999948211098),
#  (85168476791,
#   0,
#   'http://dbpedia.org/resource/Baseball_statistics',
#   'assists',
#   0.6119579946813937),
#  (85168476791,
#   0,
#   'http://dbpedia.org/resource/Hysteresis',
#   'hysteresis',
#   0.9682452705604025),
#  (85168476791,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.9999999948211098),
#  (85168476791,
#   0,
#   'http://dbpedia.org/resource/Internal_audit',
#   'internal audit',
#   1.0),
#  (85168476791,
#   0,
#   'http://dbpedia.org/resource/Soft_computing',
#   'soft computing',
#   1.0),
#  (85168476791,
#   0,
#   'http://dbpedia.org/resource/Set_theory',
#   'set theory',
#   0.9996315799171818),
#  (85168476791,
#   0,
#   'http://dbpedia.org/resource/Algorithm',
#   'algorithm',
#   0.9999460479339639),
#  (85168476791,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.9999999948211098),
#  (85168476791,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.9999999948211098),
#  (85168476791,
#   0,
#   'http://dbpedia.org/resource/Data_infrastructure',
#   'data infrastructure',
#   1.0),
#  (85168476791,
#   1,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.9999998988656722),
#  (85168476791,
#   1,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.9999998988656722),
#  (85168476791,
#   1,
#   'http://dbpedia.org/resource/Data_infrastructure',
#   'data infrastructure',
#   1.0),
#  (85168476791,
#   1,
#   'http://dbpedia.org/resource/Apparent_magnitude',
#   'magnitude',
#   0.9110009595088079),
#  (85168476791,
#   1,
#   'http://dbpedia.org/resource/Internal_audit',
#   'internal audit',
#   1.0),
#  (85168476791, 1, 'http://dbpedia.org/resource/Big_data', 'big data', 1.0),
#  (85198853040,
#   0,
#   'http://dbpedia.org/resource/Board_of_directors',
#   "directors' duties",
#   0.948482501806565),
#  (85198853040,
#   0,
#   'http://dbpedia.org/resource/Business_judgment_rule',
#   'business judgment rule',
#   1.0),
#  (85198853040,
#   0,
#   'http://dbpedia.org/resource/Rationality',
#   'rationality',
#   0.9999154664778693),
#  (85198853040,
#   0,
#   'http://dbpedia.org/resource/Insolvency',
#   'insolvency',
#   0.8452439962288453),
#  (85198853040,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'artificial intelligence',
#   0.9998944694632593),
#  (85198853040,
#   0,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.9999978237017138),
#  (85198853040,
#   1,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'artificial intelligence',
#   0.999968005997915),
#  (85198853040,
#   1,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.999951842725345),
#  (85198853040,
#   1,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.999951842725345),
#  (85198853040,
#   1,
#   'http://dbpedia.org/resource/Artificial_intelligence',
#   'AI',
#   0.999951842725345),
#  (85198853040,
#   1,
#   'http://dbpedia.org/resource/Corporate_governance',
#   'corporate governance',
#   0.9999999889737411)]

# %%
# ----------------------------------------
# Step 3 — Enrich annotations with DBpedia JSON
# ----------------------------------------
from dbpedia_pipeline import enrich_annotations

print("\nStep 3 — Enriching annotations with DBpedia entity info...")
all_enriched = enrich_annotations(all_annotations)

print(f"Total enriched entities: {len(all_enriched)}")
# optional: preview first 5
for e in all_enriched[:5]:
    print(f"- {e['label']} | Types: {e['types']} | Relations: {list(e['relations'].keys())} | Score: {e['similarity_score']}")
# Out:
# Step 3 — Enriching annotations with DBpedia entity info...
# 2025-10-20 22:03:32,526 | ERROR | Failed to fetch entity http://dbpedia.org/resource/United_States: HTTPSConnectionPool(host='dbpedia.org', port=443): Read timed out. (read timeout=10)
# 2025-10-20 22:03:32,529 | WARNING | No data for URI: http://dbpedia.org/resource/United_States
# 2025-10-20 22:03:41,922 | ERROR | Failed to fetch entity http://dbpedia.org/resource/China: 500 Server Error: SPARQL Request Failed for url: https://dbpedia.org/data/China.json
# 2025-10-20 22:03:41,923 | WARNING | No data for URI: http://dbpedia.org/resource/China
# Total enriched entities: 159
# - Artificial intelligence | Types: ['http://dbpedia.org/ontology/MusicGenre', 'http://dbpedia.org/ontology/Organisation', 'http://www.w3.org/2002/07/owl#Thing'] | Relations: ['categories'] | Score: 0.9999998141935466
# - Data governance | Types: ['http://dbpedia.org/ontology/Place'] | Relations: ['categories'] | Score: 1.0
# - Data dependency | Types: ['http://dbpedia.org/class/yago/Person100007846', 'http://dbpedia.org/ontology/ProgrammingLanguage', 'http://dbpedia.org/class/yago/Writer110794014', 'http://dbpedia.org/class/yago/Organism100004475', 'http://dbpedia.org/class/yago/LivingThing100004258', 'http://dbpedia.org/class/yago/Object100002684', 'http://dbpedia.org/class/yago/PhysicalEntity100001930', 'http://dbpedia.org/class/yago/WikicatCompilers', 'http://dbpedia.org/class/yago/YagoLegalActorGeo', 'http://dbpedia.org/class/yago/YagoLegalActor', 'http://dbpedia.org/class/yago/Compiler109946957', 'http://dbpedia.org/class/yago/Whole100003553', 'http://dbpedia.org/class/yago/CausalAgent100007347', 'http://dbpedia.org/class/yago/Communicator109610660'] | Relations: ['categories'] | Score: 1.0
# - Hinder | Types: ['http://dbpedia.org/ontology/Band', 'http://dbpedia.org/class/yago/YagoLegalActorGeo', 'http://dbpedia.org/class/yago/YagoLegalActor', 'http://dbpedia.org/class/yago/WikicatAmericanGlamMetalMusicalGroups', 'http://dbpedia.org/class/yago/Group100031264', 'http://dbpedia.org/class/yago/Organization108008335', 'http://schema.org/Organization', 'http://dbpedia.org/class/yago/MusicalOrganization108246613', 'http://schema.org/MusicGroup', 'http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Agent', 'http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#SocialPerson', 'http://dbpedia.org/class/yago/Abstraction100002137', 'http://dbpedia.org/class/yago/WikicatAmericanHardRockMusicalGroups', 'http://dbpedia.org/class/yago/WikicatAmericanPost-grungeMusicalGroups', 'http://dbpedia.org/class/yago/YagoPermanentlyLocatedEntity', 'http://dbpedia.org/class/yago/WikicatMusicalGroupsEstablishedIn2001', 'http://umbel.org/umbel/rc/Band_MusicGroup', 'http://www.w3.org/2002/07/owl#Thing', 'http://dbpedia.org/ontology/Group', 'http://dbpedia.org/class/yago/WikicatMusicalGroupsFromOklahoma', 'http://dbpedia.org/ontology/Organisation', 'http://www.wikidata.org/entity/Q43229', 'http://dbpedia.org/class/yago/SocialGroup107950920', 'http://www.wikidata.org/entity/Q215380', 'http://www.wikidata.org/entity/Q24229398', 'http://dbpedia.org/ontology/Agent'] | Relations: ['categories'] | Score: 0.9999999184987052
# - Data sharing | Types: ['http://dbpedia.org/ontology/Company'] | Relations: ['categories'] | Score: 1.0

# %%
# Collect all types seen across the dataset
all_types_seen = set()
for entity in all_enriched:
    all_types_seen.update(entity.get("types", []))

print(f"Types seen across dataset ({len(all_types_seen)}):")
print(sorted(all_types_seen))
# Out:
# Types seen across dataset (274):
# ['http://dbpedia.org/class/yago/Ability105616246', 'http://dbpedia.org/class/yago/Abstraction100002137', 'http://dbpedia.org/class/yago/Act100030358', 'http://dbpedia.org/class/yago/Activity100407535', 'http://dbpedia.org/class/yago/AdministrativeDistrict108491826', 'http://dbpedia.org/class/yago/AdministrativeUnit108077292', 'http://dbpedia.org/class/yago/Administrator109770949', 'http://dbpedia.org/class/yago/Album106591815', 'http://dbpedia.org/class/yago/Algorithm105847438', 'http://dbpedia.org/class/yago/Alliance108293982', 'http://dbpedia.org/class/yago/Application100949134', 'http://dbpedia.org/class/yago/Application106570110', 'http://dbpedia.org/class/yago/Artifact100021939', 'http://dbpedia.org/class/yago/ArtificialLanguage106894544', 'http://dbpedia.org/class/yago/Attribute100024264', 'http://dbpedia.org/class/yago/Bloc108171094', 'http://dbpedia.org/class/yago/Branch108401248', 'http://dbpedia.org/class/yago/BroadcastingStation102903405', 'http://dbpedia.org/class/yago/CausalAgent100007347', 'http://dbpedia.org/class/yago/City108524735', 'http://dbpedia.org/class/yago/Code106355894', 'http://dbpedia.org/class/yago/CodingSystem106353757', 'http://dbpedia.org/class/yago/Cognition100023271', 'http://dbpedia.org/class/yago/Collection107951464', 'http://dbpedia.org/class/yago/Communication100033020', 'http://dbpedia.org/class/yago/Communication106252138', 'http://dbpedia.org/class/yago/Communicator109610660', 'http://dbpedia.org/class/yago/Community108223802', 'http://dbpedia.org/class/yago/Company108058098', 'http://dbpedia.org/class/yago/Compiler109946957', 'http://dbpedia.org/class/yago/ComputerArchitecture106725249', 'http://dbpedia.org/class/yago/Content105809192', 'http://dbpedia.org/class/yago/Continent109254614', 'http://dbpedia.org/class/yago/CorporateExecutive109966255', 'http://dbpedia.org/class/yago/Country108544813', 'http://dbpedia.org/class/yago/Creation103129123', 'http://dbpedia.org/class/yago/DataSystem103164344', 'http://dbpedia.org/class/yago/DatabaseManagementSystem106588785', 'http://dbpedia.org/class/yago/Datum105816622', 'http://dbpedia.org/class/yago/DefiniteQuantity113576101', 'http://dbpedia.org/class/yago/Description106724763', 'http://dbpedia.org/class/yago/District108552138', 'http://dbpedia.org/class/yago/Division108220714', 'http://dbpedia.org/class/yago/Emotion107480068', 'http://dbpedia.org/class/yago/Event100029378', 'http://dbpedia.org/class/yago/Executive110069645', 'http://dbpedia.org/class/yago/ExecutiveBranch108356074', 'http://dbpedia.org/class/yago/Facility103315023', 'http://dbpedia.org/class/yago/Feeling100026192', 'http://dbpedia.org/class/yago/Food107555863', 'http://dbpedia.org/class/yago/Gathering107975026', 'http://dbpedia.org/class/yago/GeographicalArea108574314', 'http://dbpedia.org/class/yago/Group100031264', 'http://dbpedia.org/class/yago/Head110162991', 'http://dbpedia.org/class/yago/HorizontalSurface103536348', 'http://dbpedia.org/class/yago/Information105816287', 'http://dbpedia.org/class/yago/Institution108053576', 'http://dbpedia.org/class/yago/Instrumentality103575240', 'http://dbpedia.org/class/yago/Issue105814650', 'http://dbpedia.org/class/yago/Land109334396', 'http://dbpedia.org/class/yago/Landmass109335916', 'http://dbpedia.org/class/yago/Language106282651', 'http://dbpedia.org/class/yago/Law108441203', 'http://dbpedia.org/class/yago/Leader109623038', 'http://dbpedia.org/class/yago/LivingThing100004258', 'http://dbpedia.org/class/yago/Location100027167', 'http://dbpedia.org/class/yago/Magazine106595351', 'http://dbpedia.org/class/yago/Matter100020827', 'http://dbpedia.org/class/yago/Measure100033615', 'http://dbpedia.org/class/yago/Medium106254669', 'http://dbpedia.org/class/yago/Medium106261586', 'http://dbpedia.org/class/yago/Message106598915', 'http://dbpedia.org/class/yago/Municipality108626283', 'http://dbpedia.org/class/yago/MusicalOrganization108246613', 'http://dbpedia.org/class/yago/NeuralNetwork106725467', 'http://dbpedia.org/class/yago/Newspaper1 ...

# %%
# ----------------------------------------
# Step 4 — Clean & validate parsed entities
# ----------------------------------------
from dbpedia_pipeline import clean_parsed_entities

print("\nStep 5 — Cleaning & validating entities...")
all_cleaned = clean_parsed_entities(all_enriched)  # single call

print(f"Total cleaned entities: {len(all_cleaned)}")
# Out:
# 2025-10-20 22:03:43,966 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:43,968 | INFO | ❌ Rejected: Data governance (http://dbpedia.org/resource/Data_governance) | Reason: Types not in whitelist
# 2025-10-20 22:03:43,970 | INFO | ❌ Rejected: Data dependency (http://dbpedia.org/resource/Data_dependency) | Reason: Types not in whitelist
# 2025-10-20 22:03:43,972 | INFO | ✅ Accepted: Hinder (http://dbpedia.org/resource/Hinder) | Reason: All heuristics passed
# 2025-10-20 22:03:43,973 | INFO | ✅ Accepted: Data sharing (http://dbpedia.org/resource/Data_sharing) | Reason: All heuristics passed
# 2025-10-20 22:03:43,975 | INFO | ✅ Accepted: Privacy (http://dbpedia.org/resource/Privacy) | Reason: All heuristics passed
# 2025-10-20 22:03:43,976 | INFO | ✅ Accepted: Data sharing (http://dbpedia.org/resource/Data_sharing) | Reason: All heuristics passed
# 2025-10-20 22:03:43,977 | INFO | ❌ Rejected: Data governance (http://dbpedia.org/resource/Data_governance) | Reason: Types not in whitelist
# 2025-10-20 22:03:43,979 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:43,982 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:43,984 | INFO | ✅ Accepted: Mathematical optimization (http://dbpedia.org/resource/Mathematical_optimization) | Reason: All heuristics passed
# 2025-10-20 22:03:43,985 | INFO | ✅ Accepted: Digital transformation (http://dbpedia.org/resource/Digital_transformation) | Reason: All heuristics passed
# 2025-10-20 22:03:43,987 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:43,988 | INFO | ✅ Accepted: Cloud computing (http://dbpedia.org/resource/Cloud_computing) | Reason: All heuristics passed
# 2025-10-20 22:03:43,989 | INFO | ✅ Accepted: Big data (http://dbpedia.org/resource/Big_data) | Reason: All heuristics passed
# 2025-10-20 22:03:43,991 | INFO | ✅ Accepted: Blockchain (http://dbpedia.org/resource/Blockchain) | Reason: All heuristics passed
# 2025-10-20 22:03:43,992 | INFO | ✅ Accepted: The Age (http://dbpedia.org/resource/The_Age) | Reason: All heuristics passed
# 2025-10-20 22:03:43,994 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:43,996 | INFO | ✅ Accepted: European Union (http://dbpedia.org/resource/European_Union) | Reason: All heuristics passed
# 2025-10-20 22:03:43,998 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,001 | INFO | ✅ Accepted: European Union (http://dbpedia.org/resource/European_Union) | Reason: All heuristics passed
# 2025-10-20 22:03:44,002 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,005 | INFO | ✅ Accepted: European Commission (http://dbpedia.org/resource/European_Commission) | Reason: All heuristics passed
# 2025-10-20 22:03:44,006 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,036 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,044 | INFO | ✅ Accepted: European Union (http://dbpedia.org/resource/European_Union) | Reason: All heuristics passed
# 2025-10-20 22:03:44,047 | INFO | ✅ Accepted: European Union (http://dbpedia.org/resource/European_Union) | Reason: All heuristics passed
# 2025-10-20 22:03:44,054 | INFO | ✅ Accepted: European Union (http://dbpedia.org/resource/European_Union) | Reason: All heuristics passed
# 2025-10-20 22:03:44,058 | INFO | ✅ Accepted: European Union (http://dbpedia.org/resource/European_Union) | Reason: All heuristics passed
# 2025-10-20 22:03:44,059 | INFO | ✅ Accepted: Philosophy (http://dbpedia.org/resource/Philosophy) | Reason: All heuristics passed
# 2025-10-20 22:03:44,062 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,068 | INFO | ✅ Accepted: Digital transformation (http://dbpedia.org/resource/Digital_transformation) | Reason: All heuristics passed
# 2025-10-20 22:03:44,070 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,071 | INFO | ✅ Accepted: European Union (http://dbpedia.org/resource/European_Union) | Reason: All heuristics passed
# 2025-10-20 22:03:44,072 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,074 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,075 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,078 | INFO | ✅ Accepted: European Union (http://dbpedia.org/resource/European_Union) | Reason: All heuristics passed
# 2025-10-20 22:03:44,079 | INFO | ✅ Accepted: Hinder (http://dbpedia.org/resource/Hinder) | Reason: All heuristics passed
# 2025-10-20 22:03:44,085 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,089 | INFO | ✅ Accepted: Asia (http://dbpedia.org/resource/Asia) | Reason: All heuristics passed
# 2025-10-20 22:03:44,089 | INFO | ✅ Accepted: European Union (http://dbpedia.org/resource/European_Union) | Reason: All heuristics passed
# Step 5 — Cleaning & validating entities...
# 2025-10-20 22:03:44,092 | INFO | ✅ Accepted: KCMP (http://dbpedia.org/resource/KCMP) | Reason: Acronym accepted
# 2025-10-20 22:03:44,093 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,095 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,098 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,103 | INFO | ✅ Accepted: European Union (http://dbpedia.org/resource/European_Union) | Reason: All heuristics passed
# 2025-10-20 22:03:44,105 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,107 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,109 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,111 | INFO | ✅ Accepted: European Union (http://dbpedia.org/resource/European_Union) | Reason: All heuristics passed
# 2025-10-20 22:03:44,112 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,117 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,119 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,121 | INFO | ✅ Accepted: Cognition (http://dbpedia.org/resource/Cognition) | Reason: All heuristics passed
# 2025-10-20 22:03:44,123 | INFO | ✅ Accepted: Emotional self-regulation (http://dbpedia.org/resource/Emotional_self-regulation) | Reason: All heuristics passed
# 2025-10-20 22:03:44,125 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,128 | INFO | ✅ Accepted: Indonesia (http://dbpedia.org/resource/Indonesia) | Reason: All heuristics passed
# 2025-10-20 22:03:44,134 | INFO | ✅ Accepted: Energy development (http://dbpedia.org/resource/Energy_development) | Reason: All heuristics passed
# 2025-10-20 22:03:44,136 | INFO | ✅ Accepted: Renewable energy (http://dbpedia.org/resource/Renewable_energy) | Reason: All heuristics passed
# 2025-10-20 22:03:44,139 | INFO | ✅ Accepted: Energy security (http://dbpedia.org/resource/Energy_security) | Reason: All heuristics passed
# 2025-10-20 22:03:44,144 | INFO | ✅ Accepted: Energy security (http://dbpedia.org/resource/Energy_security) | Reason: All heuristics passed
# 2025-10-20 22:03:44,156 | INFO | ❌ Rejected: Rationality (http://dbpedia.org/resource/Rationality) | Reason: Score 0.939 < threshold 0.96
# 2025-10-20 22:03:44,159 | INFO | ❌ Rejected: Energy management (http://dbpedia.org/resource/Energy_management) | Reason: No types + no keywords
# 2025-10-20 22:03:44,170 | INFO | ✅ Accepted: Energy development (http://dbpedia.org/resource/Energy_development) | Reason: All heuristics passed
# 2025-10-20 22:03:44,172 | INFO | ✅ Accepted: Renewable energy (http://dbpedia.org/resource/Renewable_energy) | Reason: All heuristics passed
# 2025-10-20 22:03:44,174 | INFO | ✅ Accepted: Biomass (http://dbpedia.org/resource/Biomass) | Reason: All heuristics passed
# 2025-10-20 22:03:44,177 | INFO | ✅ Accepted: Briquette (http://dbpedia.org/resource/Briquette) | Reason: All heuristics passed
# 2025-10-20 22:03:44,179 | INFO | ✅ Accepted: Biodegradable waste (http://dbpedia.org/resource/Biodegradable_waste) | Reason: All heuristics passed
# 2025-10-20 22:03:44,192 | INFO | ✅ Accepted: Smart city (http://dbpedia.org/resource/Smart_city) | Reason: All heuristics passed
# 2025-10-20 22:03:44,195 | INFO | ✅ Accepted: City (http://dbpedia.org/resource/City) | Reason: All heuristics passed
# 2025-10-20 22:03:44,201 | INFO | ✅ Accepted: Renewable energy (http://dbpedia.org/resource/Renewable_energy) | Reason: All heuristics passed
# 2025-10-20 22:03:44,203 | INFO | ✅ Accepted: Renewable energy (http://dbpedia.org/resource/Renewable_energy) | Reason: All heuristics passed
# 2025-10-20 22:03:44,204 | INFO | ✅ Accepted: Mathematical optimization (http://dbpedia.org/resource/Mathematical_optimization) | Reason: All heuristics passed
# 2025-10-20 22:03:44,206 | INFO | ✅ Accepted: Biomass (http://dbpedia.org/resource/Biomass) | Reason: All heuristics passed
# 2025-10-20 22:03:44,208 | INFO | ✅ Accepted: Briquette (http://dbpedia.org/resource/Briquette) | Reason: All heuristics passed
# 2025-10-20 22:03:44,209 | INFO | ✅ Accepted: Mathematical optimization (http://dbpedia.org/resource/Mathematical_optimization) | Reason: All heuristics passed
# 2025-10-20 22:03:44,211 | INFO | ✅ Accepted: Biomass (http://dbpedia.org/resource/Biomass) | Reason: All heuristics passed
# 2025-10-20 22:03:44,213 | INFO | ✅ Accepted: Briquette (http://dbpedia.org/resource/Briquette) | Reason: All heuristics passed
# 2025-10-20 22:03:44,308 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,310 | INFO | ✅ Accepted: Biodegradable waste (http://dbpedia.org/resource/Biodegradable_waste) | Reason: All heuristics passed
# 2025-10-20 22:03:44,320 | INFO | ✅ Accepted: Biomass (http://dbpedia.org/resource/Biomass) | Reason: All heuristics passed
# 2025-10-20 22:03:44,322 | INFO | ✅ Accepted: Briquette (http://dbpedia.org/resource/Briquette) | Reason: All heuristics passed
# 2025-10-20 22:03:44,324 | INFO | ✅ Accepted: Biodegradable waste (http://dbpedia.org/resource/Biodegradable_waste) | Reason: All heuristics passed
# 2025-10-20 22:03:44,325 | INFO | ✅ Accepted: Biomass (http://dbpedia.org/resource/Biomass) | Reason: All heuristics passed
# 2025-10-20 22:03:44,337 | INFO | ✅ Accepted: Briquette (http://dbpedia.org/resource/Briquette) | Reason: All heuristics passed
# 2025-10-20 22:03:44,339 | INFO | ✅ Accepted: Artificial neural network (http://dbpedia.org/resource/Artificial_neural_network) | Reason: All heuristics passed
# 2025-10-20 22:03:44,342 | INFO | ✅ Accepted: Artificial neural network (http://dbpedia.org/resource/Artificial_neural_network) | Reason: All heuristics passed
# 2025-10-20 22:03:44,344 | INFO | ✅ Accepted: MATLAB (http://dbpedia.org/resource/MATLAB) | Reason: Acronym accepted
# 2025-10-20 22:03:44,346 | INFO | ✅ Accepted: Mathematical optimization (http://dbpedia.org/resource/Mathematical_optimization) | Reason: All heuristics passed
# 2025-10-20 22:03:44,352 | INFO | ✅ Accepted: Biodegradable waste (http://dbpedia.org/resource/Biodegradable_waste) | Reason: All heuristics passed
# 2025-10-20 22:03:44,354 | INFO | ✅ Accepted: Biomass (http://dbpedia.org/resource/Biomass) | Reason: All heuristics passed
# 2025-10-20 22:03:44,355 | INFO | ✅ Accepted: Biomass (http://dbpedia.org/resource/Biomass) | Reason: All heuristics passed
# 2025-10-20 22:03:44,358 | INFO | ✅ Accepted: Big data (http://dbpedia.org/resource/Big_data) | Reason: All heuristics passed
# 2025-10-20 22:03:44,360 | INFO | ✅ Accepted: Thailand (http://dbpedia.org/resource/Thailand) | Reason: All heuristics passed
# 2025-10-20 22:03:44,372 | INFO | ❌ Rejected: Data governance (http://dbpedia.org/resource/Data_governance) | Reason: Types not in whitelist
# 2025-10-20 22:03:44,374 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,375 | INFO | ✅ Accepted: Digital Government Development Agency (http://dbpedia.org/resource/Digital_Government_Development_Agency) | Reason: All heuristics passed
# 2025-10-20 22:03:44,377 | INFO | ✅ Accepted: Directors Guild of America (http://dbpedia.org/resource/Directors_Guild_of_America) | Reason: All heuristics passed
# 2025-10-20 22:03:44,379 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,386 | INFO | ✅ Accepted: Electronic business (http://dbpedia.org/resource/Electronic_business) | Reason: All heuristics passed
# 2025-10-20 22:03:44,390 | INFO | ✅ Accepted: Thailand (http://dbpedia.org/resource/Thailand) | Reason: All heuristics passed
# 2025-10-20 22:03:44,392 | INFO | ❌ Rejected: Data governance (http://dbpedia.org/resource/Data_governance) | Reason: Types not in whitelist
# 2025-10-20 22:03:44,394 | INFO | ✅ Accepted: Thailand (http://dbpedia.org/resource/Thailand) | Reason: All heuristics passed
# 2025-10-20 22:03:44,395 | INFO | ❌ Rejected: Data governance (http://dbpedia.org/resource/Data_governance) | Reason: Types not in whitelist
# 2025-10-20 22:03:44,404 | INFO | ✅ Accepted: European Union (http://dbpedia.org/resource/European_Union) | Reason: All heuristics passed
# 2025-10-20 22:03:44,407 | INFO | ✅ Accepted: General Data Protection Regulation (http://dbpedia.org/resource/General_Data_Protection_Regulation) | Reason: All heuristics passed
# 2025-10-20 22:03:44,409 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,410 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,411 | INFO | ✅ Accepted: Targeted advertising (http://dbpedia.org/resource/Targeted_advertising) | Reason: All heuristics passed
# 2025-10-20 22:03:44,412 | INFO | ✅ Accepted: Recommender system (http://dbpedia.org/resource/Recommender_system) | Reason: All heuristics passed
# 2025-10-20 22:03:44,419 | INFO | ✅ Accepted: European Union (http://dbpedia.org/resource/European_Union) | Reason: All heuristics passed
# 2025-10-20 22:03:44,421 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,422 | INFO | ✅ Accepted: European Union (http://dbpedia.org/resource/European_Union) | Reason: All heuristics passed
# 2025-10-20 22:03:44,423 | INFO | ✅ Accepted: European Union (http://dbpedia.org/resource/European_Union) | Reason: All heuristics passed
# 2025-10-20 22:03:44,425 | INFO | ✅ Accepted: General Data Protection Regulation (http://dbpedia.org/resource/General_Data_Protection_Regulation) | Reason: All heuristics passed
# 2025-10-20 22:03:44,426 | INFO | ✅ Accepted: European Union (http://dbpedia.org/resource/European_Union) | Reason: All heuristics passed
# 2025-10-20 22:03:44,428 | INFO | ✅ Accepted: Information privacy (http://dbpedia.org/resource/Information_privacy) | Reason: All heuristics passed
# 2025-10-20 22:03:44,429 | INFO | ✅ Accepted: Philosophy (http://dbpedia.org/resource/Philosophy) | Reason: All heuristics passed
# 2025-10-20 22:03:44,435 | INFO | ✅ Accepted: Ethics (http://dbpedia.org/resource/Ethics) | Reason: All heuristics passed
# 2025-10-20 22:03:44,437 | INFO | ✅ Accepted: Computer science (http://dbpedia.org/resource/Computer_science) | Reason: All heuristics passed
# 2025-10-20 22:03:44,438 | INFO | ✅ Accepted: Big data (http://dbpedia.org/resource/Big_data) | Reason: All heuristics passed
# 2025-10-20 22:03:44,439 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,441 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,444 | INFO | ✅ Accepted: Data economy (http://dbpedia.org/resource/Data_economy) | Reason: Accepted by keyword heuristic
# 2025-10-20 22:03:44,445 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,450 | INFO | ✅ Accepted: Data sharing (http://dbpedia.org/resource/Data_sharing) | Reason: All heuristics passed
# 2025-10-20 22:03:44,454 | INFO | ✅ Accepted: Data sharing (http://dbpedia.org/resource/Data_sharing) | Reason: All heuristics passed
# 2025-10-20 22:03:44,456 | INFO | ✅ Accepted: Data capitalism (http://dbpedia.org/resource/Data_capitalism) | Reason: Accepted by keyword heuristic
# 2025-10-20 22:03:44,458 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,459 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,460 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,462 | INFO | ❌ Rejected: Baseball statistics (http://dbpedia.org/resource/Baseball_statistics) | Reason: Score 0.612 < threshold 0.75
# 2025-10-20 22:03:44,470 | INFO | ✅ Accepted: Hysteresis (http://dbpedia.org/resource/Hysteresis) | Reason: All heuristics passed
# 2025-10-20 22:03:44,472 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,474 | INFO | ✅ Accepted: Internal audit (http://dbpedia.org/resource/Internal_audit) | Reason: All heuristics passed
# 2025-10-20 22:03:44,475 | INFO | ✅ Accepted: Soft computing (http://dbpedia.org/resource/Soft_computing) | Reason: All heuristics passed
# 2025-10-20 22:03:44,477 | INFO | ✅ Accepted: Set theory (http://dbpedia.org/resource/Set_theory) | Reason: All heuristics passed
# 2025-10-20 22:03:44,479 | INFO | ✅ Accepted: Algorithm (http://dbpedia.org/resource/Algorithm) | Reason: All heuristics passed
# 2025-10-20 22:03:44,759 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,761 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,762 | INFO | ✅ Accepted: Data infrastructure (http://dbpedia.org/resource/Data_infrastructure) | Reason: All heuristics passed
# 2025-10-20 22:03:44,767 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,769 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,771 | INFO | ✅ Accepted: Data infrastructure (http://dbpedia.org/resource/Data_infrastructure) | Reason: All heuristics passed
# 2025-10-20 22:03:44,773 | INFO | ✅ Accepted: Apparent magnitude (http://dbpedia.org/resource/Apparent_magnitude) | Reason: All heuristics passed
# 2025-10-20 22:03:44,774 | INFO | ✅ Accepted: Internal audit (http://dbpedia.org/resource/Internal_audit) | Reason: All heuristics passed
# 2025-10-20 22:03:44,776 | INFO | ✅ Accepted: Big data (http://dbpedia.org/resource/Big_data) | Reason: All heuristics passed
# 2025-10-20 22:03:44,778 | INFO | ✅ Accepted: Board of directors (http://dbpedia.org/resource/Board_of_directors) | Reason: All heuristics passed
# 2025-10-20 22:03:44,783 | INFO | ❌ Rejected: Business judgment rule (http://dbpedia.org/resource/Business_judgment_rule) | Reason: Types not in whitelist
# 2025-10-20 22:03:44,795 | INFO | ✅ Accepted: Rationality (http://dbpedia.org/resource/Rationality) | Reason: All heuristics passed
# 2025-10-20 22:03:44,800 | INFO | ❌ Rejected: Insolvency (http://dbpedia.org/resource/Insolvency) | Reason: Score 0.845 < threshold 0.96
# 2025-10-20 22:03:44,803 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,805 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,807 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,808 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,810 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,811 | INFO | ✅ Accepted: Artificial intelligence (http://dbpedia.org/resource/Artificial_intelligence) | Reason: All heuristics passed
# 2025-10-20 22:03:44,818 | INFO | ✅ Accepted: Corporate governance (http://dbpedia.org/resource/Corporate_governance) | Reason: All heuristics passed
# 2025-10-20 22:03:44,819 | INFO | Finished cleaning: 148 accepted, 11 rejected.
# Total cleaned entities: 148

# %%
display(all_cleaned)
# Out:
# [{'label': 'Artificial intelligence',
#   'abstract': 'Artificial intelligence (AI) is intelligence—perceiving, synthesizing, and infering information—demonstrated by machines, as opposed to intelligence displayed by animals and humans. Example tasks in which this is done include speech recognition, computer vision, translation between (natural) languages, as well as other mappings of inputs. The Oxford English Dictionary of Oxford University Press defines artificial intelligence as: the theory and development of computer systems able to perform tasks that normally require human intelligence, such as visual perception, speech recognition, decision-making, and translation between languages. AI applications include advanced web search engines (e.g., Google), recommendation systems (used by YouTube, Amazon and Netflix), understanding human speech (such as Siri and Alexa), self-driving cars (e.g., Tesla), automated decision-making and competing at the highest level in strategic game systems (such as chess and Go).As machines become increasingly capable, tasks considered to require "intelligence" are often removed from the definition of AI, a phenomenon known as the AI effect. For instance, optical character recognition is frequently excluded from things considered to be AI, having become a routine technology. Artificial intelligence was founded as an academic discipline in 1956, and in the years since has experienced several waves of optimism, followed by disappointment and the loss of funding (known as an "AI winter"), followed by new approaches, success and renewed funding. AI research has tried and discarded many different approaches since its founding, including simulating the brain, modeling human problem solving, formal logic, large databases of knowledge and imitating animal behavior. In the first decades of the 21st century, highly mathematical-statistical machine learning has dominated the field, and this technique has proved highly successful, helping to solve many challenging problems throughout industry and academia. The various sub-fields of AI research are centered around particular goals and the use of particular tools. The traditional goals of AI research include reasoning, knowledge representation, planning, learning, natural language processing, perception, and the ability to move and manipulate objects. General intelligence (the ability to solve an arbitrary problem) is among the field\'s long-term goals. To solve these problems, AI researchers have adapted and integrated a wide range of problem-solving techniques – including search and mathematical optimization, formal logic, artificial neural networks, and methods based on statistics, probability and economics. AI also draws upon computer science, psychology, linguistics, philosophy, and many other fields. The field was founded on the assumption that human intelligence "can be so precisely described that a machine can be made to simulate it".This raised philosophical arguments about the mind and the ethical consequences of creating artificial beings endowed with human-like intelligence; these issues have previously been explored by myth, fiction and philosophy since antiquity. Computer scientists and philosophers have since suggested that AI may become an existential risk to humanity if its rational capacities are not steered towards beneficial goals.',
#   'types': ['http://dbpedia.org/ontology/MusicGenre',
#    'http://dbpedia.org/ontology/Organisation',
#    'http://www.w3.org/2002/07/owl#Thing'],
#   'relations': {'categories': ['http://dbpedia.org/resource/Category:Artificial_intelligence',
#     'http://dbpedia.org/resource/Category:Computational_fields_of_study',
#     'http://dbpedia.org/resource/Category:Cybernetics',
#     'http://dbpedia.org/resource/Category:Computational_neuroscience',
#     'http://dbpedia.org/resource/Category:Unsolved_problems_in_computer_science',
#     'http://dbpedia.org/resource/Category:Emerging_technologies',
#     'http://dbpedia.org/resource/Category:Data_science',
#     'http://dbpedia.org/resource/Category:Formal_sciences']},
#   'wikidata_quids': ['Q11660'],
#   'uri': 'http://dbpedia.org/resource/Artificial_intelligence',
#   'scopus_id': 85195362067,
#   'chunk_id': 0,
#   'surface_form': 'Artificial intelligence',
#   'similarity_score': 0.9999998141935466},
#  {'label': 'Hinder',
#   'abstract': 'Hinder is an American rock band from Oklahoma City, Oklahoma, formed in 2001 by lead singer Austin John Winkler, guitarist Joe "Blower" Garvey, and drummer Cody Hanson with bassist Mike Roden and guitarist Mark King joining in 2003, solidifying the line-up. The band released four studio albums with Winkler; Extreme Behavior (2005), Take It to the Limit (2008), All American Nightmare (2010) and Welcome to the Freakshow (2012). Cody Hanson, along with former lead singer Austin Winkler, wrote the majority of the band\'s music on their first four albums. After Winkler left the band in 2013, they looked for a new lead vocalist, and added Marshal Dutton. They have since released When the Smoke Clears (2015) and The Reign (2017) with their new vocalist. Their seventh studio album is currently in the works. The band was inducted into the Oklahoma Music Hall of Fame in 2007.',
#   'types': ['http://dbpedia.org/ontology/Band',
#    'http://dbpedia.org/class/yago/YagoLegalActorGeo',
#    'http://dbpedia.org/class/yago/YagoLegalActor',
#    'http://dbpedia.org/class/yago/WikicatAmericanGlamMetalMusicalGroups',
#    'http://dbpedia.org/class/yago/Group100031264',
#    'http://dbpedia.org/class/yago/Organization108008335',
#    'http://schema.org/Organization',
#    'http://dbpedia.org/class/yago/MusicalOrganization108246613',
#    'http://schema.org/MusicGroup',
#    'http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Agent',
#    'http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#SocialPerson',
#    'http://dbpedia.org/class/yago/Abstraction100002137',
#    'http://dbpedia.org/class/yago/WikicatAmericanHardRockMusicalGroups',
#    'http://dbpedia.org/class/yago/WikicatAmericanPost-grungeMusicalGroups',
#    'http://dbpedia.org/class/yago/YagoPermanentlyLocatedEntity',
#    'http://dbpedia.org/class/yago/WikicatMusicalGroupsEstablishedIn2001',
#    'http://umbel.org/umbel/rc/Band_MusicGroup',
#    'http://www.w3.org/2002/07/owl#Thing',
#    'http://dbpedia.org/ontology/Group',
#    'http://dbpedia.org/class/yago/WikicatMusicalGroupsFromOklahoma',
#    'http://dbpedia.org/ontology/Organisation',
#    'http://www.wikidata.org/entity/Q43229',
#    'http://dbpedia.org/class/yago/SocialGroup107950920',
#    'http://www.wikidata.org/entity/Q215380',
#    'http://www.wikidata.org/entity/Q24229398',
#    'http://dbpedia.org/ontology/Agent'],
#   'relations': {'categories': ['http://dbpedia.org/resource/Category:Universal_Records_artists',
#     'http://dbpedia.org/resource/Category:Musical_quintets',
#     'http://dbpedia.org/resource/Category:Musical_groups_established_in_2001',
#     'http://dbpedia.org/resource/Category:Musical_groups_from_Oklahoma_City',
#     'http://dbpedia.org/resource/Category:American_glam_metal_musical_groups',
#     'http://dbpedia.org/resource/Category:American_hard_rock_musical_groups',
#     'http://dbpedia.org/resource/Category:Alternative_rock_groups_from_Oklahoma']},
#   'wikidata_quids': ['Q907370'],
#   'uri': 'http://dbpedia.org/resource/Hinder',
#   'scopus_id': 85195362067,
#   'chunk_id': 0,
#   'surface_form': 'hinder',
#   'similarity_score': 0.9999999184987052},
#  {'label': 'Data sharing',
#   'abstract': 'Data sharing is the practice of making data used for scholarly research available to other investigators. Many funding agencies, institutions, and publication venues have policies regarding data sharing because transparency and openness are considered by many to be part of the scientific method. A number of funding agencies and science journals require authors of peer-reviewed papers to share any supplemental information (raw data, statistical methods or source code) necessary to understand, develop or reproduce published research. A great deal of scientific research is not subject to data sharing requirements, and many of these policies have liberal exceptions. In the absence of any binding requirement, data sharing is at the discretion of the scientists themselves. In addition, in certain situations governments and institutions prohibit or severely limit data sharing to protect proprietary interests, national security, and subject/patient/victim confidentiality. Data sharing may also be restricted to protect institutions and scientists from use of data for political purposes. Data and methods may be requested from an author years after publication. In order to encourage data sharing and prevent the loss or corruption of data, a number of funding agencies and journals established policies on data archiving. Access to publicly archived data is a recent development in the history of science made possible by technological advances in communications and information technology. To take full advantage of modern rapid communication may require consensual agreement on the criteria underlying mutual recognition of respective contributions. Models recognized for improving the timely sharing of data for more effective response to emergent infectious disease threats include the data sharing mechanism introduced by the GISAID Initiative. Despite policies on data sharing and archiving, data withholding still happens. Authors may fail to archive data or they only archive a portion of the data. Failure to archive data alone is not data withholding. When a researcher requests additional information, an author sometimes refuses to provide it. When authors withhold data like this, they run the risk of losing the trust of the science community. A 2022 study identified about 3500 research papers which contained statements that the data was available, but upon request and further seeking the data, found that it was unavailable for 94% of papers. Data sharing may also indicate the sharing of personal information on a social media platform.',
#   'types': ['http://dbpedia.org/ontology/Company'],
#   'relations': {'categories': ['http://dbpedia.org/resource/Category:Scholarly_communication',
#     'http://dbpedia.org/resource/Category:Open_access_(publishing)',
#     'http://dbpedia.org/resource/Category:Data',
#     'http://dbpedia.org/resource/Category:Academic_publishing',
#     'http://dbpedia.org/resource/Category:Open_data',
#     'http://dbpedia.org/resource/Category:Sharing',
#     'http://dbpedia.org/resource/Category:Scientific_misconduct',
#     'http://dbpedia.org/resource/Category:Scientific_method',
#     'http://dbpedia.org/resource/Category:Open_science',
#     'http://dbpedia.org/resource/Category:Data_publishing']},
#   'wikidata_quids': ['Q5227350'],
#   'uri': 'http://dbpedia.org/resource/Data_sharing',
#   'scopus_id': 85195362067,
#   'chunk_id': 0,
#   'surface_form': 'data sharing',
#   'similarity_score': 1.0},
#  {'label': 'Privacy',
#   'abstract': 'Privacy (UK: /ˈprɪvəsiː/, US: /ˈpraɪ-/) is the ability of an individual or group to seclude themselves or information about themselves, and thereby express themselves selectively. The domain of privacy partially overlaps with security, which can include the concepts of appropriate use and protection of information. Privacy may also take the form of bodily integrity. The right not to be subjected to unsanctioned invasions of privacy by the government, corporations, or individuals is part of many countries\' privacy laws, and in some cases, constitutions. The concept of universal individual privacy is a modern concept primarily associated with Western culture, particularly British and North American, and remained virtually unknown in some cultures until recent times. Now, most cultures recognize the ability of individuals to withhold certain parts of personal information from wider society. With the rise of technology, the debate regarding privacy has shifted from a bodily sense to a digital sense. As the world has become digital, there have been conflicts regarding the legal right to privacy and where it is applicable. In most countries, the right to a reasonable expectation to digital privacy has been extended from the original right to privacy, and many countries, notably the US, under its agency, the Federal Trade Commission, and those within the European Union (EU), have passed acts that further protect digital privacy from public and private entities and grant additional rights to users of technology. With the rise of the Internet, there has been an increase in the prevalence of social bots, causing political polarization and harassment. Online harassment has also spiked, particularly with teenagers, which has consequently resulted in multiple privacy breaches. Selfie culture, the prominence of networks like Facebook and Instagram, location technology, and the use of advertisements and their tracking methods also pose threats to digital privacy. Through the rise of technology and immensity of the debate regarding privacy, there have been various conceptions of privacy, which include the right to be let alone as defined in "The Right to Privacy", the first U.S. publication discussing privacy as a legal right, to the theory of the privacy paradox, which describes the notion that users\' online may say they are concerned about their privacy, but in reality, are not. Along with various understandings of privacy, there are actions that reduce privacy, the most recent classification includes processing of information, sharing information, and invading personal space to get private information, as defined by Daniel J. Solove. Conversely, in order to protect a user\'s privacy, multiple steps can be taken, specifically through practicing encryption, anonymity, and taking further measures to bolster the security of their data.',
#   'types': ['http://dbpedia.org/ontology/Disease',
#    'http://dbpedia.org/ontology/MusicGenre',
#    'http://www.w3.org/2002/07/owl#Thing'],
#   'relations': {'categories': ['http://dbpedia.org/resource/Category:Civil_rights_and_liberties',
#     'http://dbpedia.org/resource/Category:Human_rights',
#     'http://dbpedia.org/resource/Category:Identity_management',
#     'http://dbpedia.org/resource/Category:Privacy',
#     'http://dbpedia.org/resource/Category:Digital_rights',
#     'http://dbpedia.org/resource/Category:Privacy_law']},
#   'wikidata_quids': ['Q188728'],
#   'uri': 'http://dbpedia.org/resource/Privacy',
#   'scopus_id': 85195362067,
#   'chunk_id': 0,
#   'surface_form': 'privacy',
#   'similarity_score': 0.9973295876647092},
#  {'label': 'Data sharing',
#   'abstract': 'Data sharing is the practice of making data used for scholarly research available to other investigators. Many funding agencies, institutions, and publication venues have policies regarding data sharing because transparency and openness are considered by many to be part of the scientific method. A number of funding agencies and science journals require authors of peer-reviewed papers to share any supplemental information (raw data, statistical methods or source code) necessary to understand, develop or reproduce published research. A great deal of scientific research is not subject to data sharing requirements, and many of these policies have liberal exceptions. In the absence of any binding requirement, data sharing is at the discretion of the scientists themselves. In addition, in certain situations governments and institutions prohibit or severely limit data sharing to protect proprietary interests, national security, and subject/patient/victim confidentiality. Data sharing may also be restricted to protect institutions and scientists from use of data for political purposes. Data and methods may be requested from an author years after publication. In order to encourage data sharing and prevent the loss or corruption of data, a number of funding agencies and journals established policies on data archiving. Access to publicly archived data is a recent development in the history of science made possible by technological advances in communications and information technology. To take full advantage of modern rapid communication may require consensual agreement on the criteria underlying mutual recognition of respective contributions. Models recognized for improving the timely sharing of data for more effective response to emergent infectious disease threats include the data sharing mechanism introduced by the GISAID Initiative. Despite policies on data sharing and archiving, data withholding still happens. Authors may fail to archive data or they only archive a portion of the data. Failure to archive data alone is not data withholding. When a researcher requests additional information, an author sometimes refuses to provide it. When authors withhold data like this, they run the risk of losing the trust of the science community. A 2022 study identified about 3500 research papers which contained statements that the data was available, but upon request and further seeking the data, found that it was unavailable for 94% of papers. Data sharing may also indicate the sharing of personal information on a social media platform.',
#   'types': ['http://dbpedia.org/ontology/Company'],
#   'relations': {'categories': ['http://dbpedia.org/resource/Category:Scholarly_communication',
#     'http://dbpedia.org/resource/Category:Open_access_(publishing)',
#     'http://dbpedia.org/resource/Category:Data',
#     'http://dbpedia.org/resource/Category:Academic_publishing',
#     'http://dbpedia.org/resource/Category:Open_data',
#     'http://dbpedia.org/resource/Category:Sharing',
#     'http://dbpedia.org/resource/Category:Scientific_misconduct',
#     'http://dbpedia.org/resource/Category:Scientific_method',
#     'http://dbpedia.org/resource/Category:Open_science',
#     'http://dbpedia.org/resource/Category:Data_publishing']},
#   'wikidata_quids': ['Q5227350'],
#   'uri': 'http://dbpedia.org/resource/Data_sharing',
#   'scopus_id': 85195362067,
#   'chunk_id': 0,
#   'surface_form': 'data sharing',
#   'similarity_score': 1.0},
#  {'label': 'Artificial intelligence',
#   'abstract': 'Artificial intelligence (AI) is intelligence—perceiving, synthesizing, and infering information—demonstrated by machines, as opposed to intelligence displayed by animals and humans. Example tasks in which this is done include speech recognition, computer vision, translation between (natural) languages, as well as other mappings of inputs. The Oxford English Dictionary of Oxford University Press defines artificial intelligence as: the theory and development of computer systems able to perform tasks that normally require human intelligence, such as visual perception, speech recognition, decision-making, and translation between languages. AI applications include advanced web search engines (e.g., Google), recommendation systems (used by YouTube, Amazon and Netflix), understanding human speech (such as Siri and Alexa), self-driving cars (e.g., Tesla), automated decision-making and competing at the highest level in strategic game systems (such as chess and Go).As machines become increasingly capable, tasks considered to require "intelligence" are often removed from the definition of AI, a phenomenon known as the AI effect. For instance, optical character recognition is frequently excluded from things considered to be AI, having become a routine technology. Artificial intelligence was founded as an academic discipline in 1956, and in the years since has experienced several waves of optimism, followed by disappointment and the loss of funding (known as an "AI winter"), followed by new approaches, success and renewed funding. AI research has tried and discarded many different approaches since its founding, including simulating the brain, modeling human problem solving, formal logic, large databases of knowledge and imitating animal behavior. In the first decades of the 21st century, highly mathematical-statistical machine learning has dominated the field, and this technique has proved highly successful, helping to solve many challenging problems throughout industry and academia. The various sub-fields of AI research are centered around particular goals and the use of particular tools. The traditional goals of AI research include reasoning, knowledge representation, planning, learning, natural language processing, perception, and the ability to move and manipulate objects. General intelligence (the ability to solve an arbitrary problem) is among the field\'s long-term goals. To solve these problems, AI researchers have adapted and integrated a wide range of problem-solving techniques – including search and mathematical optimization, formal logic, artificial neural networks, and methods based on statistics, probability and economics. AI also draws upon computer science, psychology, linguistics, philosophy, and many other fields. The field was founded on the assumption that human intelligence "can be so precisely described that a machine can be made to simulate it".This raised philosophical arguments about the mind and the ethical consequences of creating artificial beings endowed with human-like intelligence; these issues have previously been explored by myth, fiction and philosophy since antiquity. Computer scientists and philosophers have since suggested that AI may become an existential risk to humanity if its rational capacities are not steered towards beneficial goals.',
#   'types': ['http://dbpedia.org/ontology/MusicGenre',
#    'http://dbpedia.org/ontology/Organisation',
#    'http://www.w3.org/2002/07/owl#Thing'],
#   'relations': {'categories': ['http://dbpedia.org/resource/Category:Artificial_intelligence',
#     'http://dbpedia.org/resource/Category:Computational_fields_of_study',
#     'http://dbpedia.org/resource/Category:Cybernetics',
#     'http://dbpedia.org/resource/Category:Computational_neuroscience',
#     'http://dbpedia.org/resource/Category:Unsolved_problems_in_computer_science',
#     'http://dbpedia.org/resource/Category:Emerging_technologies',
#     'http://dbpedia.org/resource/Category:Data_science',
#     'http://dbpedia.org/resource/Category:Formal_sciences']},
#   'wikidata_quids': ['Q11660'],
#   'uri': 'http://dbpedia.org/resource/Artificial_intelligence',
#   'scopus_id': 85195362067,
#   'chunk_id': 0,
#   'surface_form': 'AI',
#   'similarity_score': 0.9999903076865347},
#  {'label': 'Artificial intelligence',
#   'abstract': 'Artificial intelligence (AI) is intelligence—perceiving, synthesizing, and infering information—demonstrated by machines, as opposed to intelligence displayed by animals and humans. Example tasks in which this is done include speech recognition, computer vision, translation between (natural) languages, as well as other mappings of inputs. The Oxford English Dictionary of Oxford University Press defines artificial intelligence as: the theory and development of computer systems able to perform tasks that normally require human intelligence, such as visual perception, speech recognition, decision-making, and translation between languages. AI applications include advanced web search engines (e.g., Google), recommendation systems (used by YouTube, Amazon and Netflix), understanding human speech (such as Siri and Alexa), self-driving cars (e.g., Tesla), automated decision-making and competing at the highest level in strategic game systems (such as chess and Go).As machines become increasingly capable, tasks considered to require "intelligence" are often removed from the definition of AI, a phenomenon known as the AI effect. For instance, optical character recognition is frequently excluded from things considered to be AI, having become a routine technology. Artificial intelligence was founded as an academic discipline in 1956, and in the years since has experienced several waves of optimism, followed by disappointment and the loss of funding (known as an "AI winter"), followed by new approaches, success and renewed funding. AI research has tried and discarded many different approaches since its founding, including simulating the brain, modeling human problem solving, formal logic, large databases of knowledge and imitating animal behavior. In the first decades of the 21st century, highly mathematical-statistical machine learning has dominated the field, and this technique has proved highly successful, helping to solve many challenging problems throughout industry and academia. The various sub-fields of AI research are centered around particular goals and the use of particular tools. The traditional goals of AI research include reasoning, knowledge representation, planning, learning, natural language processing, perception, and the ability to move and manipulate objects. General intelligence (the ability to solve an arbitrary problem) is among the field\'s long-term goals. To solve these problems, AI researchers have adapted and integrated a wide range of problem-solving techniques – including search and mathematical optimization, formal logic, artificial neural networks, and methods based on statistics, probability and economics. AI also draws upon computer science, psychology, linguistics, philosophy, and many other fields. The field was founded on the assumption that human intelligence "can be so precisely described that a machine can be made to simulate it".This raised philosophical arguments about the mind and the ethical consequences of creating artificial beings endowed with human-like intelligence; these issues have previously been explored by myth, fiction and philosophy since antiquity. Computer scientists and philosophers have since suggested that AI may become an existential risk to humanity if its rational capacities are not steered towards beneficial goals.',
#   'types': ['http://dbpedia.org/ontology/MusicGenre',
#    'http://dbpedia.org/ontology/Organisation',
#    'http://www.w3.org/2002/07/owl#Thing'],
#   'relations': {'categories': ['http://dbpedia.org/resource/Category:Artificial_intelligence',
#     'http://dbpedia.org/resource/Category:Computational_fields_of_study',
#     'http://dbpedia.org/resource/Category:Cybernetics',
#     'http://dbpedia.org/resource/Category:Computational_neuroscience',
#     'http://dbpedia.org/resource/Category:Unsolved_problems_in_computer_science',
#     'http://dbpedia.org/resource/Category:Emerging_technologies',
#     'http://dbpedia.org/resource/Category:Data_science',
#     'http://dbpedia.org/resource/Category:Formal_sciences']},
#   'wikidata_quids': ['Q11660'],
#   'uri': 'http://dbpedia.org/resource/Artificial_intelligence',
#   'scopus_id': 85195362067,
#   'chunk_id': 0,
#   'surface_form': 'AI',
#   'similarity_score': 0.9999903076865347},
#  {'label': 'Mathematical optimization',
#   'abstract': 'Mathematical optimization (alternatively spelled optimisation) or mathematical programming is the selection of a best element, with regard to some criterion, from some set of available alternatives. It is generally divided into two subfields: discrete optimization and continuous optimization. Optimization problems of sorts arise in all quantitative disciplines from computer science and engineering to operations research and economics, and the development of solution methods has been of interest in mathematics for centuries. In the more general approach, an optimization problem consists of maximizing or minimizing a real function by systematically choosing input values from within an allowed set and computing the value of the function. The generalization of optimization theory and techniques to other formulations constitutes a large area of applied mathematics. More generally, optimization includes finding "best available" values of some objective function given a defined domain (or input), including a variety of different types of objective functions and different types of domains.',
#   'types': ['http://dbpedia.org/ontology/CultivatedVariety',
#    'http://dbpedia.org/ontology/MusicGenre',
#    'http://www.w3.org/2002/07/owl#Thing'],
#   'relations': {'categories': ['http://dbpedia.org/resource/Category:Operations_research',
#     'http://dbpedia.org/resource/Category:Mathematical_optimization',
#     'http://dbpedia.org/resource/Category:Mathematical_and_quantitative_methods_(economics)']},
#   'wikidata_quids': ['Q141495', 'Q1971426'],
#   'uri': 'http://dbpedia.org/resource/Mathematical_optimization',
#   'scopus_id': 85195362067,
#   'chunk_id': 1,
#   'surface_form': 'optimization',
#   'similarity_score': 0.9924677316381805},
#  {'label': 'Digital transformation',
#   'abstract': 'Digital transformation (DX) is the adoption of digital technology by an organization to digitize non-digital products, services or operations. The goal for its implementation is to increase value through innovation, invention, customer experience or efficiency.',
#   'types': ['http://www.w3.org/2002/07/owl#Thing'],
#   'relations': {'categories': ['http://dbpedia.org/resource/Category:Business_planning',
#     'http://dbpedia.org/resource/Category:Digital_technology']},
#   'wikidata_quids': ['Q4252370'],
#   'uri': 'http://dbpedia.org/resource/Digital_transformation',
#   'scopus_id': 85181155120,
#   'chunk_id': 0,
#   'surface_form': 'digital transformation',
#   'similarity_score': 1.0},
#  {'label': 'Artificial intelligence',
#   'abstract': 'Artificial intelligence (AI) is intelligence—perceiving, synthesizing, and infering information—demonstrated by machines, as opposed to intelligence displayed by animals and humans. Example tasks in which this is done include speech recognition, computer vision, translation between (natural) languages, as well as other mappings of inputs. The Oxford English Dictionary of Oxford University Press defines artificial intelligence as: the theory and development of computer systems able to perform tasks that normally require human intelligence, such as visual perception, speech recognition, decision-making, and translation between languages. AI applications include advanced web search engines (e.g., Google), recommendation systems (used by YouTube, Amazon and Netflix), understanding human speech (such as Siri and Alexa), self-driving cars (e.g., Tesla), automated decision-making and competing at the highest level in strategic game systems (such as chess and Go).As machines become increasingly capable, tasks considered to require "intelligence" are often removed from the definition of AI, a phenomenon known as the AI effect. For instance, optical character recognition is frequently excluded from things considered to be AI, having become a routine technology. Artificial intelligence was founded as an academic discipline in 1956, and in the years since has experienced several waves of optimism, followed by disappointment and the loss of funding (known as an "AI winter"), followed by new approaches, success and renewed funding. AI research has tried and discarded many different approaches since its founding, including simulating the brain, modeling human problem solving, formal logic, large databases of knowledge and imitating animal behavior. In the first decades of the 21st century, highly mathematical-statistical machine learning has dominated the field, and this technique has proved highly successful, helping to solve many challenging problems throughout industry and academia. The various sub-fields of AI research are centered around particular goals and the use of particular tools. The traditional goals of AI research include reasoning, knowledge representation, planning, learning, natural language processing, perception, and the ability to move and manipulate objects. General intelligence (the ability to solve an arbitrary problem) is among the field\'s long-term goals. To solve these problems, AI researchers have adapted and integrated a wide range of problem-solving techniques – including search and mathematical optimization, formal logic, artificial neural networks, and methods based on statistics, probability and economics. AI also draws upon computer science, psychology, linguistics, philosophy, and many other fields. The field was founded on the assumption that human intelligence "can be so precisely described that a machine can be made to simulate it".This raised philosophical arguments about the mind and the ethical consequences of creating artificial beings endowed with human-like intelligence; these issues have previously been explored by myth, fiction and philosophy since antiquity. Computer scientists and philosophers have since suggested that AI may become an existential risk to humanity if its rational capacities are not steered towards beneficial goals.',
#   'types': ['http://dbpedia.org/ontology/MusicGenre',
#    'http://dbpedia.org/ontology/Organisation',
#    'http://www.w3.org/2002/07/owl#Thing'],
#   'relations': {'categories': ['http://dbpedia.org/resource/Category:Artificial_intelligence',
#     'http://dbpedia.org/resource/Category:Computational_fields_of_study',
#     'http://dbpedia.org/resource/Category:Cybernetics',
#     'http://dbpedia.org/resource/Category:Computational_neuroscience',
#     'http://dbpedia.org/resource/Category:Unsolved_problems_in_computer_science',
#     'http://dbpedia.org/resource/Category:Emerging_technologies',
#     'http://dbpedia.org/resource/Category:Data_science',
#     'http://dbpedia.org/resource/Category:Formal_sciences']},
#   'wikidata_quids': ['Q11660'],
#   'uri': 'http://dbpedia.org/resource/Artificial_intelligence',
#   'scopus_id': 85181155120,
#   'chunk_id': 0,
#   'surface_form': 'AI',
#   'similarity_score': 0.9999999999791953},
#  {'label': 'Cloud computing',
#   'abstract': 'Cloud computing is the on-demand availability of computer system resources, especially data storage (cloud storage) and computing power, without direct active management by the user. Large clouds often have functions distributed over multiple locations, each of which is a data center. Cloud computing relies on sharing of resources to achieve coherence and typically uses a "pay as you go" model, which can help in reducing capital expenses but may also lead to unexpected operating expenses for users.',
#   'types': ['http://dbpedia.org/class/yago/Instrumentality103575240',
#    'http://dbpedia.org/class/yago/Medium106254669',
#    'http://dbpedia.org/class/yago/Whole100003553',
#    'http://dbpedia.org/class/yago/Object100002684',
#    'http://dbpedia.org/class/yago/PhysicalEntity100001930',
#    'http://dbpedia.org/class/yago/Artifact100021939',
#    'http://www.w3.org/2002/07/owl#Thing',
#    'http://dbpedia.org/class/yago/HorizontalSurface103536348',
#    'http://dbpedia.org/ontology/MusicGenre',
#    'http://dbpedia.org/class/yago/Platform103961939',
#    'http://dbpedia.org/class/yago/Surface104362025',
#    'http://dbpedia.org/class/yago/Telecommunication106271778',
#    'http://dbpedia.org/class/yago/WikicatTelecommunications',
#    'http://dbpedia.org/class/yago/WikicatCloudPlatforms'],
#   'relations': {'categories': ['http://dbpedia.org/resource/Category:Cloud_infrastructure',
#     'http://dbpedia.org/resource/Category:Cloud_computing']},
#   'wikidata_quids': ['Q483639'],
#   'uri': 'http://dbpedia.org/resource/Cloud_computing',
#   'scopus_id': 85181155120,
#   'chunk_id': 0,
#   'surface_form': 'cloud computing',
#   'similarity_score': 1.0},
#  {'label': 'Big data',
#   'abstract': 'Big data refers to data sets that are too large or complex to be dealt with by traditional data-processing application software. Data with many fields (rows) offer greater statistical power, while data with higher complexity (more attributes or columns) may lead to a higher false discovery rate. Big data analysis challenges include capturing data, data storage, data analysis, search, sharing, transfer, visualization, querying, updating, information privacy, and data source. Big data was originally associated with three key concepts: volume, variety, and velocity. The analysis of big data presents challenges in sampling, and thus previously allowing for only observations and sampling. Thus a fourth concept, veracity, refers to the quality or insightfulness of the data. Without sufficient investment in expertise for big data veracity, then the volume and variety of data can produce costs and risks that exceed an organization\'s capacity to create and capture value from big data. Current usage of the term big data tends to refer to the use of predictive analytics, user behavior analytics, or certain other advanced data analytics methods that extract value from big data, and seldom to a particular size of data set. "There is little doubt that the quantities of data now available are indeed large, but that\'s not the most relevant characteristic of this new data ecosystem."Analysis of data sets can find new correlations to "spot business trends, prevent diseases, combat crime and so on". Scientists, business executives, medical practitioners, advertising and governments alike regularly meet difficulties with large data-sets in areas including Internet searches, fintech, healthcare analytics, geographic information systems, urban informatics, and business informatics. Scientists encounter limitations in e-Science work, including meteorology, genomics, connectomics, complex physics simulations, biology, and environmental research. The size and number of available data sets have grown rapidly as data is collected by devices such as mobile devices, cheap and numerous information-sensing Internet of things devices, aerial (remote sensing), software logs, cameras, microphones, radio-frequency identification (RFID) readers and wireless sensor networks. The world\'s technological per-capita capacity to store information has roughly doubled every 40 months since the 1980s; as of 2012, every day 2.5 exabytes (2.5×260 bytes) of data are generated. Based on an IDC report prediction, the global data volume was predicted to grow exponentially from 4.4 zettabytes to 44 zettabytes between 2013 and 2020. By 2025, IDC predicts there will be 163 zettabytes of data. According to IDC, global spending on big data and business analytics (BDA) solutions is estimated to reach $215.7 billion in 2021. While Statista report, the global big data market is forecasted to grow to $103 billion by 2027. In 2011 McKinsey & Company reported, if US healthcare were to use big data creatively and effectively to drive efficiency and quality, the sector could create more than $300 billion in value every year. In the developed economies of Europe, government administrators could save more than €100 billion ($149 billion) in operational efficiency improvements alone by using big data. And users of services enabled by personal-location data could capture $600 billion in consumer surplus. One question for large enterprises is determining who should own big-data initiatives that affect the entire organization. Relational database management systems and desktop statistical software packages used to visualize data often have difficulty processing and analyzing big data. The processing and analysis of big data may require "massively parallel software running on tens, hundreds, or even thousands of servers". What qualifies as "big data" varies depending on the capabilities of those analyzing it and their tools. Furthermore, expanding capabilities make big data a mov ...
#   'types': ['http://dbpedia.org/class/yago/WikicatDatabaseManagementSystems',
#    'http://dbpedia.org/class/yago/WikicatEmergingTechnologies',
#    'http://dbpedia.org/class/yago/Profession100609953',
#    'http://dbpedia.org/class/yago/Technology100949619',
#    'http://dbpedia.org/class/yago/Application100949134',
#    'http://dbpedia.org/class/yago/Use100947128',
#    'http://www.w3.org/2002/07/owl#Thing',
#    'http://dbpedia.org/class/yago/Communication100033020',
#    'http://dbpedia.org/class/yago/Cognition100023271',
#    'http://dbpedia.org/class/yago/PsychologicalFeature100023100',
#    'http://dbpedia.org/class/yago/YagoPermanentlyLocatedEntity',
#    'http://dbpedia.org/class/yago/Abstraction100002137',
#    'http://dbpedia.org/class/yago/Event100029378',
#    'http://dbpedia.org/class/yago/Information105816287',
#    'http://dbpedia.org/class/yago/Occupation100582388',
#    'http://dbpedia.org/class/yago/Writing106359877',
#    'http://dbpedia.org/class/yago/Code106355894',
#    'http://dbpedia.org/class/yago/Act100030358',
#    'http://dbpedia.org/class/yago/Software106566077',
#    'http://dbpedia.org/class/yago/Activity100407535',
#    'http://dbpedia.org/class/yago/WrittenCommunication106349220',
#    'http://dbpedia.org/class/yago/CodingSystem106353757',
#    'http://dbpedia.org/class/yago/DatabaseManagementSystem106588785',
#    'http://dbpedia.org/ontology/MusicGenre',
#    'http://dbpedia.org/class/yago/WikicatBigData',
#    'http://dbpedia.org/class/yago/Datum105816622'],
#   'relations': {'categories': ['http://dbpedia.org/resource/Category:Transaction_processing',
#     'http://dbpedia.org/resource/Category:Data_management',
#     'http://dbpedia.org/resource/Category:Big_data',
#     'http://dbpedia.org/resource/Category:Technology_forecasting',
#     'http://dbpedia.org/resource/Category:Distributed_computing_problems',
#     'http://dbpedia.org/resource/Category:Databases',
#     'http://dbpedia.org/resource/Category:Data_analysis']},
#   'wikidata_quids': ['Q858810'],
#   'uri': 'http://dbpedia.org/resource/Big_data',
#   'scopus_id': 85181155120,
#   'chunk_id': 0,
#   'surface_form': 'big data',
#   'similarity_score': 1.0},
#  {'label': 'Blockchain',
#   'abstract': 'A blockchain is a type of distributed ledger technology (DLT) that consists of growing lists of records, called blocks, that are securely linked together using cryptography. Each block contains a cryptographic hash of the previous block, a timestamp, and transaction data (generally represented as a Merkle tree, where data nodes are represented by leaves). The timestamp proves that the transaction data existed when the block was created. Since each block contains information about the previous block, they effectively form a chain (compare linked list data structure), with each additional block linking to the ones before it. Consequently, blockchain transactions are irreversible in that, once they are recorded, the data in any given block cannot be altered retroactively without altering all subsequent blocks. Blockchains are typically managed by a peer-to-peer (P2P) computer network for use as a public distributed ledger, where nodes collectively adhere to a consensus algorithm protocol to add and validate new transaction blocks. Although blockchain records are not unalterable, since blockchain forks are possible, blockchains may be considered secure by design and exemplify a distributed computing system with high Byzantine fault tolerance. A blockchain was created by a person (or group of people) using the name (or pseudonym) Satoshi Nakamoto in 2008 to serve as the public distributed ledger for bitcoin cryptocurrency transactions, based on previous work by Stuart Haber, W. Scott Stornetta, and Dave Bayer. The implementation of the blockchain within bitcoin made it the first digital currency to solve the double-spending problem without the need of a trusted authority or central server. The bitcoin design has inspired other applications and blockchains that are readable by the public and are widely used by cryptocurrencies. The blockchain may be considered a type of payment rail. Private blockchains have been proposed for business use. Computerworld called the marketing of such privatized blockchains without a proper security model "snake oil"; however, others have argued that permissioned blockchains, if carefully designed, may be more decentralized and therefore more secure in practice than permissionless ones.',
#   'types': ['http://www.w3.org/2002/07/owl#Thing'],
#   'relations': {'categories': ['http://dbpedia.org/resource/Category:Blockchains',
#     'http://dbpedia.org/resource/Category:Bitcoin',
#     'http://dbpedia.org/resource/Category:Cryptocurrencies',
#     'http://dbpedia.org/resource/Category:Decentralization',
#     'http://dbpedia.org/resource/Category:Encodings',
#     'http://dbpedia.org/resource/Category:Database_models',
#     'http://dbpedia.org/resource/Category:Mathematical_tools',
#     'http://dbpedia.org/resource/Category:Writing_systems',
#     'http://dbpedia.org/resource/Category:Computer-related_introductions_in_2009',
#     'http://dbpedia.org/resource/Category:Emerging_technologies',
#     'http://dbpedia.org/resource/Category:Information_systems',
#     'http://dbpedia.org/resource/Category:Counting_instruments',
#     'http://dbpedia.org/resource/Category:21st-century_inventions',
#     'http://dbpedia.org/resource/Category:Financial_metadata']},
#   'wikidata_quids': ['Q20514253'],
#   'uri': 'http://dbpedia.org/resource/Blockchain',
#   'scopus_id': 85181155120,
#   'chunk_id': 0,
#   'surface_form': 'blockchain',
#   'similarity_score': 0.9999997604824389},
#  {'label': 'The Age',
#   'abstract': "The Age is a daily newspaper in Melbourne, Australia, that has been published since 1854. Owned and published by Nine Entertainment, The Age primarily serves Victoria, but copies also sell in Tasmania, the Australian Capital Territory and border regions of South Australia and southern New South Wales. It is delivered both in print and digital formats. The newspaper shares some articles with its sister newspaper The Sydney Morning Herald. The Age is considered a newspaper of record for Australia, and has variously been known for its investigative reporting, with its journalists having won dozens of Walkley Awards, Australia's most prestigious journalism prize. As of March 2020, The Age had a monthly readership of 5.321 million.",
#   'types': ['http://dbpedia.org/class/yago/WikicatNewspapersPublishedInMelbourne',
#    'http://dbpedia.org/class/yago/Instrumentality103575240',
#    'http://dbpedia.org/class/yago/Medium106254669',
#    'http://dbpedia.org/class/yago/Newspaper106267145',
#    'http://dbpedia.org/ontology/Newspaper',
#    'http://dbpedia.org/class/yago/WikicatEnglish-languageNewspapers',
#    'http://dbpedia.org/class/yago/Magazine106595351',
#    'http://dbpedia.org/class/yago/PrintMedia106263609',
#    'http://dbpedia.org/class/yago/Work104599396',
#    'http://dbpedia.org/class/yago/Publication106589574',
#    'http://dbpedia.org/class/yago/Whole100003553',
#    'http://dbpedia.org/class/yago/Object100002684',
#    'http://dbpedia.org/ontology/WrittenWork',
#    'http://dbpedia.org/class/yago/Press106263369',
#    'http://dbpedia.org/ontology/PeriodicalLiterature',
#    'http://www.wikidata.org/entity/Q386724',
#    'http://www.w3.org/2002/07/owl#Thing',
#    'http://www.wikidata.org/entity/Q234460',
#    'http://dbpedia.org/class/yago/Creation103129123',
#    'http://dbpedia.org/ontology/Work',
#    'http://www.wikidata.org/entity/Q1092563',
#    'http://www.wikidata.org/entity/Q11032',
#    'http://dbpedia.org/class/yago/Product104007894',
#    'http://dbpedia.org/class/yago/WikicatPublicationsEstablishedIn1854',
#    'http://schema.org/CreativeWork',
#    'http://dbpedia.org/class/yago/PhysicalEntity100001930',
#    'http://dbpedia.org/class/yago/Artifact100021939',
#    'http://dbpedia.org/class/yago/WikicatNewspapersPublishedInAustralia'],
#   'relations': {'categories': ['http://dbpedia.org/resource/Category:Daily_newspapers_published_in_Australia',
#     'http://dbpedia.org/resource/Category:1854_establishments_in_Australia',
#     'http://dbpedia.org/resource/Category:Australian_news_websites',
#     'http://dbpedia.org/resource/Category:Fairfax_Media',
#     'http://dbpedia.org/resource/Category:Fairfax_family_(publishers)',
#     'http://dbpedia.org/resource/Category:Newspapers_established_in_1854',
#     'http://dbpedia.org/resource/Category:Nine_Entertainment',
#     'http://dbpedia.org/resource/Category:Newspapers_published_in_Melbourne']},
#   'wikidata_quids': ['Q631893'],
#   'uri': 'http://dbpedia.org/resource/The_Age',
#   'scopus_id': 85181155120,
#   'chunk_id': 0,
#   'surface_form': 'The Age',
#   'similarity_score': 1.0},
#  {'label': 'Artificial intelligence',
# ...
#   'scopus_id': 85198853040,
#   'chunk_id': 1,
#   'surface_form': 'artificial intelligence',
#   'similarity_score': 0.999968005997915},
#  {'label': 'Artificial intelligence',
#   'abstract': 'Artificial intelligence (AI) is intelligence—perceiving, synthesizing, and infering information—demonstrated by machines, as opposed to intelligence displayed by animals and humans. Example tasks in which this is done include speech recognition, computer vision, translation between (natural) languages, as well as other mappings of inputs. The Oxford English Dictionary of Oxford University Press defines artificial intelligence as: the theory and development of computer systems able to perform tasks that normally require human intelligence, such as visual perception, speech recognition, decision-making, and translation between languages. AI applications include advanced web search engines (e.g., Google), recommendation systems (used by YouTube, Amazon and Netflix), understanding human speech (such as Siri and Alexa), self-driving cars (e.g., Tesla), automated decision-making and competing at the highest level in strategic game systems (such as chess and Go).As machines become increasingly capable, tasks considered to require "intelligence" are often removed from the definition of AI, a phenomenon known as the AI effect. For instance, optical character recognition is frequently excluded from things considered to be AI, having become a routine technology. Artificial intelligence was founded as an academic discipline in 1956, and in the years since has experienced several waves of optimism, followed by disappointment and the loss of funding (known as an "AI winter"), followed by new approaches, success and renewed funding. AI research has tried and discarded many different approaches since its founding, including simulating the brain, modeling human problem solving, formal logic, large databases of knowledge and imitating animal behavior. In the first decades of the 21st century, highly mathematical-statistical machine learning has dominated the field, and this technique has proved highly successful, helping to solve many challenging problems throughout industry and academia. The various sub-fields of AI research are centered around particular goals and the use of particular tools. The traditional goals of AI research include reasoning, knowledge representation, planning, learning, natural language processing, perception, and the ability to move and manipulate objects. General intelligence (the ability to solve an arbitrary problem) is among the field\'s long-term goals. To solve these problems, AI researchers have adapted and integrated a wide range of problem-solving techniques – including search and mathematical optimization, formal logic, artificial neural networks, and methods based on statistics, probability and economics. AI also draws upon computer science, psychology, linguistics, philosophy, and many other fields. The field was founded on the assumption that human intelligence "can be so precisely described that a machine can be made to simulate it".This raised philosophical arguments about the mind and the ethical consequences of creating artificial beings endowed with human-like intelligence; these issues have previously been explored by myth, fiction and philosophy since antiquity. Computer scientists and philosophers have since suggested that AI may become an existential risk to humanity if its rational capacities are not steered towards beneficial goals.',
#   'types': ['http://dbpedia.org/ontology/MusicGenre',
#    'http://dbpedia.org/ontology/Organisation',
#    'http://www.w3.org/2002/07/owl#Thing'],
#   'relations': {'categories': ['http://dbpedia.org/resource/Category:Artificial_intelligence',
#     'http://dbpedia.org/resource/Category:Computational_fields_of_study',
#     'http://dbpedia.org/resource/Category:Cybernetics',
#     'http://dbpedia.org/resource/Category:Computational_neuroscience',
#     'http://dbpedia.org/resource/Category:Unsolved_problems_in_computer_science',
#     'http://dbpedia.org/resource/Category:Emerging_technologies',
#     'http://dbpedia.org/resource/Category:Data_science',
#     'http://dbpedia.org/resource/Category:Formal_sciences']},
#   'wikidata_quids': ['Q11660'],
#   'uri': 'http://dbpedia.org/resource/Artificial_intelligence',
#   'scopus_id': 85198853040,
#   'chunk_id': 1,
#   'surface_form': 'AI',
#   'similarity_score': 0.999951842725345},
#  {'label': 'Artificial intelligence',
#   'abstract': 'Artificial intelligence (AI) is intelligence—perceiving, synthesizing, and infering information—demonstrated by machines, as opposed to intelligence displayed by animals and humans. Example tasks in which this is done include speech recognition, computer vision, translation between (natural) languages, as well as other mappings of inputs. The Oxford English Dictionary of Oxford University Press defines artificial intelligence as: the theory and development of computer systems able to perform tasks that normally require human intelligence, such as visual perception, speech recognition, decision-making, and translation between languages. AI applications include advanced web search engines (e.g., Google), recommendation systems (used by YouTube, Amazon and Netflix), understanding human speech (such as Siri and Alexa), self-driving cars (e.g., Tesla), automated decision-making and competing at the highest level in strategic game systems (such as chess and Go).As machines become increasingly capable, tasks considered to require "intelligence" are often removed from the definition of AI, a phenomenon known as the AI effect. For instance, optical character recognition is frequently excluded from things considered to be AI, having become a routine technology. Artificial intelligence was founded as an academic discipline in 1956, and in the years since has experienced several waves of optimism, followed by disappointment and the loss of funding (known as an "AI winter"), followed by new approaches, success and renewed funding. AI research has tried and discarded many different approaches since its founding, including simulating the brain, modeling human problem solving, formal logic, large databases of knowledge and imitating animal behavior. In the first decades of the 21st century, highly mathematical-statistical machine learning has dominated the field, and this technique has proved highly successful, helping to solve many challenging problems throughout industry and academia. The various sub-fields of AI research are centered around particular goals and the use of particular tools. The traditional goals of AI research include reasoning, knowledge representation, planning, learning, natural language processing, perception, and the ability to move and manipulate objects. General intelligence (the ability to solve an arbitrary problem) is among the field\'s long-term goals. To solve these problems, AI researchers have adapted and integrated a wide range of problem-solving techniques – including search and mathematical optimization, formal logic, artificial neural networks, and methods based on statistics, probability and economics. AI also draws upon computer science, psychology, linguistics, philosophy, and many other fields. The field was founded on the assumption that human intelligence "can be so precisely described that a machine can be made to simulate it".This raised philosophical arguments about the mind and the ethical consequences of creating artificial beings endowed with human-like intelligence; these issues have previously been explored by myth, fiction and philosophy since antiquity. Computer scientists and philosophers have since suggested that AI may become an existential risk to humanity if its rational capacities are not steered towards beneficial goals.',
#   'types': ['http://dbpedia.org/ontology/MusicGenre',
#    'http://dbpedia.org/ontology/Organisation',
#    'http://www.w3.org/2002/07/owl#Thing'],
#   'relations': {'categories': ['http://dbpedia.org/resource/Category:Artificial_intelligence',
#     'http://dbpedia.org/resource/Category:Computational_fields_of_study',
#     'http://dbpedia.org/resource/Category:Cybernetics',
#     'http://dbpedia.org/resource/Category:Computational_neuroscience',
#     'http://dbpedia.org/resource/Category:Unsolved_problems_in_computer_science',
#     'http://dbpedia.org/resource/Category:Emerging_technologies',
#     'http://dbpedia.org/resource/Category:Data_science',
#     'http://dbpedia.org/resource/Category:Formal_sciences']},
#   'wikidata_quids': ['Q11660'],
#   'uri': 'http://dbpedia.org/resource/Artificial_intelligence',
#   'scopus_id': 85198853040,
#   'chunk_id': 1,
#   'surface_form': 'AI',
#   'similarity_score': 0.999951842725345},
#  {'label': 'Artificial intelligence',
#   'abstract': 'Artificial intelligence (AI) is intelligence—perceiving, synthesizing, and infering information—demonstrated by machines, as opposed to intelligence displayed by animals and humans. Example tasks in which this is done include speech recognition, computer vision, translation between (natural) languages, as well as other mappings of inputs. The Oxford English Dictionary of Oxford University Press defines artificial intelligence as: the theory and development of computer systems able to perform tasks that normally require human intelligence, such as visual perception, speech recognition, decision-making, and translation between languages. AI applications include advanced web search engines (e.g., Google), recommendation systems (used by YouTube, Amazon and Netflix), understanding human speech (such as Siri and Alexa), self-driving cars (e.g., Tesla), automated decision-making and competing at the highest level in strategic game systems (such as chess and Go).As machines become increasingly capable, tasks considered to require "intelligence" are often removed from the definition of AI, a phenomenon known as the AI effect. For instance, optical character recognition is frequently excluded from things considered to be AI, having become a routine technology. Artificial intelligence was founded as an academic discipline in 1956, and in the years since has experienced several waves of optimism, followed by disappointment and the loss of funding (known as an "AI winter"), followed by new approaches, success and renewed funding. AI research has tried and discarded many different approaches since its founding, including simulating the brain, modeling human problem solving, formal logic, large databases of knowledge and imitating animal behavior. In the first decades of the 21st century, highly mathematical-statistical machine learning has dominated the field, and this technique has proved highly successful, helping to solve many challenging problems throughout industry and academia. The various sub-fields of AI research are centered around particular goals and the use of particular tools. The traditional goals of AI research include reasoning, knowledge representation, planning, learning, natural language processing, perception, and the ability to move and manipulate objects. General intelligence (the ability to solve an arbitrary problem) is among the field\'s long-term goals. To solve these problems, AI researchers have adapted and integrated a wide range of problem-solving techniques – including search and mathematical optimization, formal logic, artificial neural networks, and methods based on statistics, probability and economics. AI also draws upon computer science, psychology, linguistics, philosophy, and many other fields. The field was founded on the assumption that human intelligence "can be so precisely described that a machine can be made to simulate it".This raised philosophical arguments about the mind and the ethical consequences of creating artificial beings endowed with human-like intelligence; these issues have previously been explored by myth, fiction and philosophy since antiquity. Computer scientists and philosophers have since suggested that AI may become an existential risk to humanity if its rational capacities are not steered towards beneficial goals.',
#   'types': ['http://dbpedia.org/ontology/MusicGenre',
#    'http://dbpedia.org/ontology/Organisation',
#    'http://www.w3.org/2002/07/owl#Thing'],
#   'relations': {'categories': ['http://dbpedia.org/resource/Category:Artificial_intelligence',
#     'http://dbpedia.org/resource/Category:Computational_fields_of_study',
#     'http://dbpedia.org/resource/Category:Cybernetics',
#     'http://dbpedia.org/resource/Category:Computational_neuroscience',
#     'http://dbpedia.org/resource/Category:Unsolved_problems_in_computer_science',
#     'http://dbpedia.org/resource/Category:Emerging_technologies',
#     'http://dbpedia.org/resource/Category:Data_science',
#     'http://dbpedia.org/resource/Category:Formal_sciences']},
#   'wikidata_quids': ['Q11660'],
#   'uri': 'http://dbpedia.org/resource/Artificial_intelligence',
#   'scopus_id': 85198853040,
#   'chunk_id': 1,
#   'surface_form': 'AI',
#   'similarity_score': 0.999951842725345},
#  {'label': 'Corporate governance',
#   'abstract': 'Corporate governance is defined, described or delineated in diverse ways, depending on the writer\'s purpose. Writers focused on a disciplinary interest or context (such as accounting, finance, law, or management) often adopt narrow definitions that appear purpose-specific. Writers concerned with regulatory policy in relation to corporate governance practices often use broader structural descriptions. A broad (meta) definition that encompasses many adopted definitions is "Corporate governance” describes the processes, structures, and mechanisms that influence the control and direction of corporations." This meta definition accommodates both the narrow definitions used in specific contexts and the broader descriptions that are often presented as authoritative. The latter include: the structural definition from the Cadbury Report, which identifies corporate governance as "the system by which companies are directed and controlled" (Cadbury 1992, p. 15); and the relational-structural view adopted by the Organization for Economic Cooperation and Development (OECD) of "Corporate governance involves a set of relationships between a company\'s management, its board, its shareholders and other stakeholders. Corporate governance also provides the structure through which the objectives of the company are set, and the means of attaining those objectives and monitoring performance are determined" (OECD 2015, p.9).',
#   'types': ['http://dbpedia.org/class/yago/Person100007846',
#    'http://dbpedia.org/class/yago/Leader109623038',
#    'http://dbpedia.org/class/yago/YagoLegalActorGeo',
#    'http://dbpedia.org/class/yago/YagoLegalActor',
#    'http://dbpedia.org/class/yago/WikicatCorporateExecutives',
#    'http://dbpedia.org/class/yago/Executive110069645',
#    'http://www.w3.org/2002/07/owl#Thing',
#    'http://dbpedia.org/class/yago/PhysicalEntity100001930',
#    'http://dbpedia.org/class/yago/Head110162991',
#    'http://dbpedia.org/class/yago/CorporateExecutive109966255',
#    'http://dbpedia.org/class/yago/Administrator109770949',
#    'http://dbpedia.org/class/yago/Whole100003553',
#    'http://dbpedia.org/class/yago/Object100002684',
#    'http://dbpedia.org/class/yago/CausalAgent100007347',
#    'http://dbpedia.org/class/yago/LivingThing100004258',
#    'http://dbpedia.org/class/yago/Organism100004475'],
#   'relations': {'categories': ['http://dbpedia.org/resource/Category:Corporate_governance',
#     'http://dbpedia.org/resource/Category:Corporate_law',
#     'http://dbpedia.org/resource/Category:Information_governance',
#     'http://dbpedia.org/resource/Category:Management',
#     'http://dbpedia.org/resource/Category:Records_management']},
#   'wikidata_quids': ['Q380767', 'Q1553864'],
#   'uri': 'http://dbpedia.org/resource/Corporate_governance',
#   'scopus_id': 85198853040,
#   'chunk_id': 1,
#   'surface_form': 'corporate governance',
#   'similarity_score': 0.9999999889737411}]

# %%
pd.DataFrame(all_cleaned).head()
# Out:
#                      label                                           abstract  \
# 0  Artificial intelligence  Artificial intelligence (AI) is intelligence—p...
# 1                   Hinder  Hinder is an American rock band from Oklahoma ...
# 2             Data sharing  Data sharing is the practice of making data us...
# 3                  Privacy  Privacy (UK: /ˈprɪvəsiː/, US: /ˈpraɪ-/) is the...
# 4             Data sharing  Data sharing is the practice of making data us...
#
#                                                types  \
# 0  [http://dbpedia.org/ontology/MusicGenre, http:...
# 1  [http://dbpedia.org/ontology/Band, http://dbpe...
# 2              [http://dbpedia.org/ontology/Company]
# 3  [http://dbpedia.org/ontology/Disease, http://d...
# 4              [http://dbpedia.org/ontology/Company]
#
#                                            relations wikidata_quids  \
# 0  {'categories': ['http://dbpedia.org/resource/C...       [Q11660]
# 1  {'categories': ['http://dbpedia.org/resource/C...      [Q907370]
# 2  {'categories': ['http://dbpedia.org/resource/C...     [Q5227350]
# 3  {'categories': ['http://dbpedia.org/resource/C...      [Q188728]
# 4  {'categories': ['http://dbpedia.org/resource/C...     [Q5227350]
#
#                                                  uri    scopus_id  chunk_id  \
# 0  http://dbpedia.org/resource/Artificial_intelli...  85195362067         0
# 1                 http://dbpedia.org/resource/Hinder  85195362067         0
# 2           http://dbpedia.org/resource/Data_sharing  85195362067         0
# 3                http://dbpedia.org/resource/Privacy  85195362067         0
# 4           http://dbpedia.org/resource/Data_sharing  85195362067         0
#
#               surface_form  similarity_score
# 0  Artificial intelligence           1.00000
# 1                   hinder           1.00000
# 2             data sharing           1.00000
# 3                  privacy           0.99733
# 4             data sharing           1.00000

# %%
import requests

def fetch_dbpedia_entity(uri):
    """
    Given a DBpedia URI, fetch its JSON data.
    Returns the inner JSON block corresponding to the entity.
    """
    try:
        # Example: uri = "http://dbpedia.org/resource/Artificial_intelligence"
        entity_name = uri.split("/")[-1]
        url = f"https://dbpedia.org/data/{entity_name}.json"
        resp = requests.get(url, timeout=10)
        resp.raise_for_status()

        data = resp.json()
        entity_key = f"http://dbpedia.org/resource/{entity_name}"
        if entity_key in data:
            return data[entity_key]
        else:
            raise KeyError(f"No data found for {entity_name}")
    except Exception as e:
        print(f"Error fetching {uri}: {e}")
        return None
